# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sn

from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split, GroupShuffleSplit 

import glob
import sys
import os
import math
import gc
import sys
import sklearn
import scipy

print(f'Tensorflow V{tf.__version__}')
print(f'Keras V{tf.keras.__version__}')
print(f'Python V{sys.version}')
# Out:
# Tensorflow V2.11.0
# Keras V2.11.0
# Python V3.7.12 | packaged by conda-forge | (default, Oct 26 2021, 06:08:53)
# [GCC 9.4.0]

# %%
# MatplotLib Global Settings
mpl.rcParams.update(mpl.rcParamsDefault)
mpl.rcParams['xtick.labelsize'] = 16
mpl.rcParams['ytick.labelsize'] = 16
mpl.rcParams['axes.labelsize'] = 18
mpl.rcParams['axes.titlesize'] = 24

# %%
# If True, processing data from scratch
# If False, loads preprocessed data
PREPROCESS_DATA = False
TRAIN_MODEL = True
# True: use 10% of participants as validation set
# False: use all data for training -> gives better LB result
USE_VAL = False

N_ROWS = 543
N_DIMS = 3
DIM_NAMES = ['x', 'y', 'z']
SEED = 42
NUM_CLASSES = 250
IS_INTERACTIVE = os.environ['KAGGLE_KERNEL_RUN_TYPE'] == 'Interactive'
VERBOSE = 1 if IS_INTERACTIVE else 2

INPUT_SIZE = 64

BATCH_ALL_SIGNS_N = 3
BATCH_SIZE = 256
N_EPOCHS =250
LR_MAX = 1e-3
# LR_MAX = 0.005 # #3
# LR_MAX = 0.00155 # #3
N_WARMUP_EPOCHS = 50
WD_RATIO = 0.05
MASK_VAL = 4237

# %%
# Prints Shape and Dtype For List Of Variables
def print_shape_dtype(l, names):
    for e, n in zip(l, names):
        print(f'{n} shape: {e.shape}, dtype: {e.dtype}')

# %%
# Read Training Data
if IS_INTERACTIVE or not PREPROCESS_DATA:
    train = pd.read_csv('/kaggle/input/asl-signs/train.csv').sample(int(5e3), random_state=SEED)
else:
    train = pd.read_csv('/kaggle/input/asl-signs/train.csv')

N_SAMPLES = len(train)
print(f'N_SAMPLES: {N_SAMPLES}')
# Out:
# N_SAMPLES: 5000

# %%
# Get complete file path to file
def get_file_path(path):
    return f'/kaggle/input/asl-signs/{path}'

train['file_path'] = train['path'].apply(get_file_path)

# %%
# Add ordinally Encoded Sign (assign number to each sign name)
train['sign_ord'] = train['sign'].astype('category').cat.codes

# Dictionaries to translate sign <-> ordinal encoded sign
SIGN2ORD = train[['sign', 'sign_ord']].set_index('sign').squeeze().to_dict()
ORD2SIGN = train[['sign_ord', 'sign']].set_index('sign_ord').squeeze().to_dict()

# %%
N = int(1e3) if (IS_INTERACTIVE or not PREPROCESS_DATA) else int(10e3)
N_UNIQUE_FRAMES = np.zeros(N, dtype=np.uint16)
N_MISSING_FRAMES = np.zeros(N, dtype=np.uint16)
MAX_FRAME = np.zeros(N, dtype=np.uint16)

PERCENTILES = [0.01, 0.05, 0.25, 0.50, 0.75, 0.95, 0.99, 0.999]

for idx, file_path in enumerate(tqdm(train['file_path'].sample(N, random_state=SEED))):
    df = pd.read_parquet(file_path)
    N_UNIQUE_FRAMES[idx] = df['frame'].nunique()
    N_MISSING_FRAMES[idx] = (df['frame'].max() - df['frame'].min()) - df['frame'].nunique() + 1
    MAX_FRAME[idx] = df['frame'].max()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
USE_TYPES = ['left_hand', 'pose', 'right_hand']
START_IDX = 468
LIPS_IDXS0 = np.array([
        61, 185, 40, 39, 37, 0, 267, 269, 270, 409,
        291, 146, 91, 181, 84, 17, 314, 405, 321, 375,
        78, 191, 80, 81, 82, 13, 312, 311, 310, 415,
        95, 88, 178, 87, 14, 317, 402, 318, 324, 308,
    ])
# Landmark indices in original data
LEFT_HAND_IDXS0 = np.arange(468,489)
RIGHT_HAND_IDXS0 = np.arange(522,543)
LEFT_POSE_IDXS0 = np.array([502, 504, 506, 508, 510])
RIGHT_POSE_IDXS0 = np.array([503, 505, 507, 509, 511])
LANDMARK_IDXS_LEFT_DOMINANT0 = np.concatenate((LIPS_IDXS0, LEFT_HAND_IDXS0, LEFT_POSE_IDXS0))
LANDMARK_IDXS_RIGHT_DOMINANT0 = np.concatenate((LIPS_IDXS0, RIGHT_HAND_IDXS0, RIGHT_POSE_IDXS0))
HAND_IDXS0 = np.concatenate((LEFT_HAND_IDXS0, RIGHT_HAND_IDXS0), axis=0)
N_COLS = LANDMARK_IDXS_LEFT_DOMINANT0.size
# Landmark indices in processed data
LIPS_IDXS = np.argwhere(np.isin(LANDMARK_IDXS_LEFT_DOMINANT0, LIPS_IDXS0)).squeeze()
LEFT_HAND_IDXS = np.argwhere(np.isin(LANDMARK_IDXS_LEFT_DOMINANT0, LEFT_HAND_IDXS0)).squeeze()
RIGHT_HAND_IDXS = np.argwhere(np.isin(LANDMARK_IDXS_LEFT_DOMINANT0, RIGHT_HAND_IDXS0)).squeeze()
HAND_IDXS = np.argwhere(np.isin(LANDMARK_IDXS_LEFT_DOMINANT0, HAND_IDXS0)).squeeze()
POSE_IDXS = np.argwhere(np.isin(LANDMARK_IDXS_LEFT_DOMINANT0, LEFT_POSE_IDXS0)).squeeze()

print(f'# HAND_IDXS: {len(HAND_IDXS)}, N_COLS: {N_COLS}')
# Out:
# # HAND_IDXS: 21, N_COLS: 66

# %%
LIPS_START = 0
LEFT_HAND_START = LIPS_IDXS.size
RIGHT_HAND_START = LEFT_HAND_START + LEFT_HAND_IDXS.size
POSE_START = RIGHT_HAND_START + RIGHT_HAND_IDXS.size

print(f'LIPS_START: {LIPS_START}, LEFT_HAND_START: {LEFT_HAND_START}, RIGHT_HAND_START: {RIGHT_HAND_START}, POSE_START: {POSE_START}')
# Out:
# LIPS_START: 0, LEFT_HAND_START: 40, RIGHT_HAND_START: 61, POSE_START: 61

# %%
# Source: https://www.kaggle.com/competitions/asl-signs/overview/evaluation
ROWS_PER_FRAME = 543  # number of landmarks per frame

def load_relevant_data_subset(pq_path):
    data_columns = ['x', 'y', 'z']
    data = pd.read_parquet(pq_path, columns=data_columns)
    n_frames = int(len(data) / ROWS_PER_FRAME)
    data = data.values.reshape(n_frames, ROWS_PER_FRAME, len(data_columns))
    return data.astype(np.float32)

# %%
"""
    Tensorflow layer to process data in TFLite
    Data needs to be processed in the model itself, so we can not use Python
""" 
class PreprocessLayer(tf.keras.layers.Layer):
    def __init__(self):
        super(PreprocessLayer, self).__init__()
        normalisation_correction = tf.constant([
                    # Add 0.50 to left hand (original right hand) and substract 0.50 of right hand (original left hand)
                    [0] * len(LIPS_IDXS) + [0.50] * len(LEFT_HAND_IDXS) + [0.50] * len(POSE_IDXS),
                    # Y coordinates stay intact
                    [0] * len(LANDMARK_IDXS_LEFT_DOMINANT0),
                    # Z coordinates stay intact
                    [0] * len(LANDMARK_IDXS_LEFT_DOMINANT0),
                ],
                dtype=tf.float32,
            )
        self.normalisation_correction = tf.transpose(normalisation_correction, [1,0])
        
    def pad_edge(self, t, repeats, side):
        if side == 'LEFT':
            return tf.concat((tf.repeat(t[:1], repeats=repeats, axis=0), t), axis=0)
        elif side == 'RIGHT':
            return tf.concat((t, tf.repeat(t[-1:], repeats=repeats, axis=0)), axis=0)
    
    @tf.function(
        input_signature=(tf.TensorSpec(shape=[None,N_ROWS,N_DIMS], dtype=tf.float32),),
    )
    def call(self, data0):
        # Number of Frames in Video
        N_FRAMES0 = tf.shape(data0)[0]
        
        # Find dominant hand by comparing summed absolute coordinates
        left_hand_sum = tf.math.reduce_sum(tf.where(tf.math.is_nan(tf.gather(data0, LEFT_HAND_IDXS0, axis=1)), 0, 1))
        right_hand_sum = tf.math.reduce_sum(tf.where(tf.math.is_nan(tf.gather(data0, RIGHT_HAND_IDXS0, axis=1)), 0, 1))
        left_dominant = left_hand_sum >= right_hand_sum
        
        # Count non NaN Hand values in each frame for the dominant hand
        if left_dominant:
            frames_hands_non_nan_sum = tf.math.reduce_sum(
                    tf.where(tf.math.is_nan(tf.gather(data0, LEFT_HAND_IDXS0, axis=1)), 0, 1),
                    axis=[1, 2],
                )
        else:
            frames_hands_non_nan_sum = tf.math.reduce_sum(
                    tf.where(tf.math.is_nan(tf.gather(data0, RIGHT_HAND_IDXS0, axis=1)), 0, 1),
                    axis=[1, 2],
                )
        
        # Find frames indices with coordinates of dominant hand
        non_empty_frames_idxs = tf.where(frames_hands_non_nan_sum > 0)
        non_empty_frames_idxs = tf.squeeze(non_empty_frames_idxs, axis=1)
        # Filter frames
        data = tf.gather(data0, non_empty_frames_idxs, axis=0)
        
        # Cast Indices in float32 to be compatible with Tensorflow Lite
        non_empty_frames_idxs = tf.cast(non_empty_frames_idxs, tf.float32)
        # Normalize to start with 0
        non_empty_frames_idxs -= tf.reduce_min(non_empty_frames_idxs)
        
        # Number of Frames in Filtered Video
        N_FRAMES = tf.shape(data)[0]
        
        # Gather Relevant Landmark Columns
        if left_dominant:
            data = tf.gather(data, LANDMARK_IDXS_LEFT_DOMINANT0, axis=1)
        else:
            data = tf.gather(data, LANDMARK_IDXS_RIGHT_DOMINANT0, axis=1)
            data = (
                    self.normalisation_correction + (
                        (data - self.normalisation_correction) * tf.where(self.normalisation_correction != 0, -1.0, 1.0))
                )
        
        # Video fits in INPUT_SIZE
        if N_FRAMES < INPUT_SIZE:
            # Pad With -1 to indicate padding
            non_empty_frames_idxs = tf.pad(non_empty_frames_idxs, [[0, INPUT_SIZE-N_FRAMES]], constant_values=-1)
            # Pad Data With Zeros
            data = tf.pad(data, [[0, INPUT_SIZE-N_FRAMES], [0,0], [0,0]], constant_values=0)
            # Fill NaN Values With 0
            data = tf.where(tf.math.is_nan(data), 0.0, data)
            return data, non_empty_frames_idxs
        # Video needs to be downsampled to INPUT_SIZE
        else:
            # Repeat
            if N_FRAMES < INPUT_SIZE**2:
                repeats = tf.math.floordiv(INPUT_SIZE * INPUT_SIZE, N_FRAMES0)
                data = tf.repeat(data, repeats=repeats, axis=0)
                non_empty_frames_idxs = tf.repeat(non_empty_frames_idxs, repeats=repeats, axis=0)

            # Pad To Multiple Of Input Size
            pool_size = tf.math.floordiv(len(data), INPUT_SIZE)
            if tf.math.mod(len(data), INPUT_SIZE) > 0:
                pool_size += 1

            if pool_size == 1:
                pad_size = (pool_size * INPUT_SIZE) - len(data)
            else:
                pad_size = (pool_size * INPUT_SIZE) % len(data)

            # Pad Start/End with Start/End value
            pad_left = tf.math.floordiv(pad_size, 2) + tf.math.floordiv(INPUT_SIZE, 2)
            pad_right = tf.math.floordiv(pad_size, 2) + tf.math.floordiv(INPUT_SIZE, 2)
            if tf.math.mod(pad_size, 2) > 0:
                pad_right += 1

            # Pad By Concatenating Left/Right Edge Values
            data = self.pad_edge(data, pad_left, 'LEFT')
            data = self.pad_edge(data, pad_right, 'RIGHT')

            # Pad Non Empty Frame Indices
            non_empty_frames_idxs = self.pad_edge(non_empty_frames_idxs, pad_left, 'LEFT')
            non_empty_frames_idxs = self.pad_edge(non_empty_frames_idxs, pad_right, 'RIGHT')

            # Reshape to Mean Pool
            data = tf.reshape(data, [INPUT_SIZE, -1, N_COLS, N_DIMS])
            non_empty_frames_idxs = tf.reshape(non_empty_frames_idxs, [INPUT_SIZE, -1])

            # Mean Pool
            data = tf.experimental.numpy.nanmean(data, axis=1)
            non_empty_frames_idxs = tf.experimental.numpy.nanmean(non_empty_frames_idxs, axis=1)

            # Fill NaN Values With 0
            data = tf.where(tf.math.is_nan(data), 0.0, data)
            
            return data, non_empty_frames_idxs
    
preprocess_layer = PreprocessLayer()

# %%
def get_data(file_path):
    # Load Raw Data
    data = load_relevant_data_subset(file_path)
    # Process Data Using Tensorflow
    data = preprocess_layer(data)
    
    return data

# %%
# Get the full dataset
def preprocess_data():
    # Create arrays to save data
    X = np.zeros([N_SAMPLES, INPUT_SIZE, N_COLS, N_DIMS], dtype=np.float32)
    y = np.zeros([N_SAMPLES], dtype=np.int32)
    NON_EMPTY_FRAME_IDXS = np.full([N_SAMPLES, INPUT_SIZE], -1, dtype=np.float32)

    # Fill X/y
    for row_idx, (file_path, sign_ord) in enumerate(tqdm(train[['file_path', 'sign_ord']].values)):
        # Log message every 5000 samples
        if row_idx % 5000 == 0:
            print(f'Generated {row_idx}/{N_SAMPLES}')

        data, non_empty_frame_idxs = get_data(file_path)
        X[row_idx] = data
        y[row_idx] = sign_ord
        NON_EMPTY_FRAME_IDXS[row_idx] = non_empty_frame_idxs
        # Sanity check, data should not contain NaN values
        if np.isnan(data).sum() > 0:
            print(row_idx)
            return data

    # Save X/y
    np.save('X.npy', X)
    np.save('y.npy', y)
    np.save('NON_EMPTY_FRAME_IDXS.npy', NON_EMPTY_FRAME_IDXS)
    
    # Save Validation
    splitter = GroupShuffleSplit(test_size=0.10, n_splits=2, random_state=SEED)
    PARTICIPANT_IDS = train['participant_id'].values
    train_idxs, val_idxs = next(splitter.split(X, y, groups=PARTICIPANT_IDS))

    # Save Train
    X_train = X[train_idxs]
    NON_EMPTY_FRAME_IDXS_TRAIN = NON_EMPTY_FRAME_IDXS[train_idxs]
    y_train = y[train_idxs]
    np.save('X_train.npy', X_train)
    np.save('y_train.npy', y_train)
    np.save('NON_EMPTY_FRAME_IDXS_TRAIN.npy', NON_EMPTY_FRAME_IDXS_TRAIN)
    # Save Validation
    X_val = X[val_idxs]
    NON_EMPTY_FRAME_IDXS_VAL = NON_EMPTY_FRAME_IDXS[val_idxs]
    y_val = y[val_idxs]
    np.save('X_val.npy', X_val)
    np.save('y_val.npy', y_val)
    np.save('NON_EMPTY_FRAME_IDXS_VAL.npy', NON_EMPTY_FRAME_IDXS_VAL)
    # Split Statistics
    print(f'Patient ID Intersection Train/Val: {set(PARTICIPANT_IDS[train_idxs]).intersection(PARTICIPANT_IDS[val_idxs])}')
    print(f'X_train shape: {X_train.shape}, X_val shape: {X_val.shape}')
    print(f'y_train shape: {y_train.shape}, y_val shape: {y_val.shape}')

# %%
# Preprocess All Data From Scratch
if PREPROCESS_DATA:
    preprocess_data()
    ROOT_DIR = '.'
else:
    ROOT_DIR = '/kaggle/input/gislr-dataset-public'
    
# Load Data
if USE_VAL:
    # Load Train
    X_train = np.load(f'{ROOT_DIR}/X_train.npy')
    y_train = np.load(f'{ROOT_DIR}/y_train.npy')
    NON_EMPTY_FRAME_IDXS_TRAIN = np.load(f'{ROOT_DIR}/NON_EMPTY_FRAME_IDXS_TRAIN.npy')
    # Load Val
    X_val = np.load(f'{ROOT_DIR}/X_val.npy')
    y_val = np.load(f'{ROOT_DIR}/y_val.npy')
    NON_EMPTY_FRAME_IDXS_VAL = np.load(f'{ROOT_DIR}/NON_EMPTY_FRAME_IDXS_VAL.npy')
    # Define validation Data
    validation_data = ({ 'frames': X_val, 'non_empty_frame_idxs': NON_EMPTY_FRAME_IDXS_VAL }, y_val)
else:
    X_train = np.load(f'{ROOT_DIR}/X.npy')
    y_train = np.load(f'{ROOT_DIR}/y.npy')
    NON_EMPTY_FRAME_IDXS_TRAIN = np.load(f'{ROOT_DIR}/NON_EMPTY_FRAME_IDXS.npy')
    validation_data = None

# Train 
print_shape_dtype([X_train, y_train, NON_EMPTY_FRAME_IDXS_TRAIN], ['X_train', 'y_train', 'NON_EMPTY_FRAME_IDXS_TRAIN'])
# Val
if USE_VAL:
    print_shape_dtype([X_val, y_val, NON_EMPTY_FRAME_IDXS_VAL], ['X_val', 'y_val', 'NON_EMPTY_FRAME_IDXS_VAL'])
# Sanity Check
print(f'# NaN Values X_train: {np.isnan(X_train).sum()}')
# Out:
# X_train shape: (94477, 64, 66, 3), dtype: float32
# y_train shape: (94477,), dtype: int32
# NON_EMPTY_FRAME_IDXS_TRAIN shape: (94477, 64), dtype: float32
# # NaN Values X_train: 0

# %%
# Class Count
display(pd.Series(y_train).value_counts().to_frame('Class Count').iloc[[0,1,2,3,4, -5,-4,-3,-2,-1]])
# Out:
#      Class Count
# 135          415
# 136          414
# 194          411
# 60           410
# 148          408
# 56           312
# 170          312
# 21           310
# 231          307
# 249          299

# %%
N_EMPTY_FRAMES = (NON_EMPTY_FRAME_IDXS_TRAIN != -1).sum(axis=1) 
N_EMPTY_FRAMES_WATERFALL = []
for n in tqdm(range(1,INPUT_SIZE+1)):
    N_EMPTY_FRAMES_WATERFALL.append(sum(N_EMPTY_FRAMES >= n) / len(NON_EMPTY_FRAME_IDXS_TRAIN) * 100)
# Out:
#   0%|          | 0/64 [00:00<?, ?it/s]

# %%
# Percentage of frames filled, this is the maximum fill percentage of each landmark
P_DATA_FILLED = (NON_EMPTY_FRAME_IDXS_TRAIN != -1).sum() / NON_EMPTY_FRAME_IDXS_TRAIN.size * 100
print(f'P_DATA_FILLED: {P_DATA_FILLED:.2f}%')
# Out:
# P_DATA_FILLED: 31.46%

# %%
# Percentage of Lips Measurements
P_LEFT_LIPS_MEASUREMENTS = (X_train[:,:,LIPS_IDXS] != 0).sum() / X_train[:,:,LIPS_IDXS].size / P_DATA_FILLED * 1e4
print(f'P_LEFT_LIPS_MEASUREMENTS: {P_LEFT_LIPS_MEASUREMENTS:.2f}%')
# Out:
# P_LEFT_LIPS_MEASUREMENTS: 99.40%

# %%
def get_lips_mean_std():
    # LIPS
    LIPS_MEAN_X = np.zeros([LIPS_IDXS.size], dtype=np.float32)
    LIPS_MEAN_Y = np.zeros([LIPS_IDXS.size], dtype=np.float32)
    LIPS_STD_X = np.zeros([LIPS_IDXS.size], dtype=np.float32)
    LIPS_STD_Y = np.zeros([LIPS_IDXS.size], dtype=np.float32)

    fig, axes = plt.subplots(3, 1, figsize=(15, N_DIMS*6))

    for col, ll in enumerate(tqdm( np.transpose(X_train[:,:,LIPS_IDXS], [2,3,0,1]).reshape([LIPS_IDXS.size, N_DIMS, -1]) )):
        for dim, l in enumerate(ll):
            v = l[np.nonzero(l)]
            if dim == 0: # X
                LIPS_MEAN_X[col] = v.mean()
                LIPS_STD_X[col] = v.std()
            if dim == 1: # Y
                LIPS_MEAN_Y[col] = v.mean()
                LIPS_STD_Y[col] = v.std()

            axes[dim].boxplot(v, notch=False, showfliers=False, positions=[col], whis=[5,95])

    for ax, dim_name in zip(axes, DIM_NAMES):
        ax.set_title(f'Lips {dim_name.upper()} Dimension', size=24)
        ax.tick_params(axis='x', labelsize=8)
        ax.grid(axis='y')

    plt.subplots_adjust(hspace=0.50)
    plt.show()

    LIPS_MEAN = np.array([LIPS_MEAN_X, LIPS_MEAN_Y]).T
    LIPS_STD = np.array([LIPS_STD_X, LIPS_STD_Y]).T
    
    return LIPS_MEAN, LIPS_STD

LIPS_MEAN, LIPS_STD = get_lips_mean_std()
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]

# %%
# Verify Normalised to Left Hand Dominant
P_LEFT_HAND_MEASUREMENTS = (X_train[:,:,LEFT_HAND_IDXS] != 0).sum() / X_train[:,:,LEFT_HAND_IDXS].size / P_DATA_FILLED * 1e4
# P_RIGHT_HAND_MEASUREMENTS = (X_train[:,:,RIGHT_HAND_IDXS] != 0).sum() / X_train[:,:,RIGHT_HAND_IDXS].size / P_DATA_FILLED * 1e4
print(f'P_LEFT_HAND_MEASUREMENTS: {P_LEFT_HAND_MEASUREMENTS:.2f}%')
# Out:
# P_LEFT_HAND_MEASUREMENTS: 100.00%

# %%
def get_left_right_hand_mean_std():
    # LEFT HAND
    LEFT_HANDS_MEAN_X = np.zeros([LEFT_HAND_IDXS.size], dtype=np.float32)
    LEFT_HANDS_MEAN_Y = np.zeros([LEFT_HAND_IDXS.size], dtype=np.float32)
    LEFT_HANDS_STD_X = np.zeros([LEFT_HAND_IDXS.size], dtype=np.float32)
    LEFT_HANDS_STD_Y = np.zeros([LEFT_HAND_IDXS.size], dtype=np.float32)

    fig, axes = plt.subplots(3, 1, figsize=(15, N_DIMS*6))

    for col, ll in enumerate(tqdm( np.transpose(X_train[:,:,LEFT_HAND_IDXS], [2,3,0,1]).reshape([LEFT_HAND_IDXS.size, N_DIMS, -1]) )):
        for dim, l in enumerate(ll):
            v = l[np.nonzero(l)]
            if dim == 0: # X
                LEFT_HANDS_MEAN_X[col] = v.mean()
                LEFT_HANDS_STD_X[col] = v.std()
            if dim == 1: # Y
                LEFT_HANDS_MEAN_Y[col] = v.mean()
                LEFT_HANDS_STD_Y[col] = v.std()
            # Plot
            axes[dim].boxplot(v, notch=False, showfliers=False, positions=[col], whis=[5,95])

    for ax, dim_name in zip(axes, DIM_NAMES):
        ax.set_title(f'Hands {dim_name.upper()} Dimension', size=24)
        ax.tick_params(axis='x', labelsize=8)
        ax.grid(axis='y')

    plt.subplots_adjust(hspace=0.50)
    plt.show()

    LEFT_HANDS_MEAN = np.array([LEFT_HANDS_MEAN_X, LEFT_HANDS_MEAN_Y]).T
    LEFT_HANDS_STD = np.array([LEFT_HANDS_STD_X, LEFT_HANDS_STD_Y]).T
    
    return LEFT_HANDS_MEAN, LEFT_HANDS_STD

LEFT_HANDS_MEAN, LEFT_HANDS_STD = get_left_right_hand_mean_std()
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]

# %%
# Percentage of Lips Measurements
P_POSE_MEASUREMENTS = (X_train[:,:,POSE_IDXS] != 0).sum() / X_train[:,:,POSE_IDXS].size / P_DATA_FILLED * 1e4
print(f'P_POSE_MEASUREMENTS: {P_POSE_MEASUREMENTS:.2f}%')
# Out:
# P_POSE_MEASUREMENTS: 100.00%

# %%
def get_pose_mean_std():
    # POSE
    POSE_MEAN_X = np.zeros([POSE_IDXS.size], dtype=np.float32)
    POSE_MEAN_Y = np.zeros([POSE_IDXS.size], dtype=np.float32)
    POSE_STD_X = np.zeros([POSE_IDXS.size], dtype=np.float32)
    POSE_STD_Y = np.zeros([POSE_IDXS.size], dtype=np.float32)

    fig, axes = plt.subplots(3, 1, figsize=(15, N_DIMS*6))

    for col, ll in enumerate(tqdm( np.transpose(X_train[:,:,POSE_IDXS], [2,3,0,1]).reshape([POSE_IDXS.size, N_DIMS, -1]) )):
        for dim, l in enumerate(ll):
            v = l[np.nonzero(l)]
            if dim == 0: # X
                POSE_MEAN_X[col] = v.mean()
                POSE_STD_X[col] = v.std()
            if dim == 1: # Y
                POSE_MEAN_Y[col] = v.mean()
                POSE_STD_Y[col] = v.std()

            axes[dim].boxplot(v, notch=False, showfliers=False, positions=[col], whis=[5,95])

    for ax, dim_name in zip(axes, DIM_NAMES):
        ax.set_title(f'Pose {dim_name.upper()} Dimension', size=24)
        ax.tick_params(axis='x', labelsize=8)
        ax.grid(axis='y')

    plt.subplots_adjust(hspace=0.50)
    plt.show()

    POSE_MEAN = np.array([POSE_MEAN_X, POSE_MEAN_Y]).T
    POSE_STD = np.array([POSE_STD_X, POSE_STD_Y]).T
    
    return POSE_MEAN, POSE_STD

POSE_MEAN, POSE_STD = get_pose_mean_std()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
# Custom sampler to get a batch containing N times all signs
def get_train_batch_all_signs(X, y, NON_EMPTY_FRAME_IDXS, n=BATCH_ALL_SIGNS_N):
    # Arrays to store batch in
    X_batch = np.zeros([NUM_CLASSES*n, INPUT_SIZE, N_COLS, N_DIMS], dtype=np.float32)
    y_batch = np.arange(0, NUM_CLASSES, step=1/n, dtype=np.float32).astype(np.int64)
    non_empty_frame_idxs_batch = np.zeros([NUM_CLASSES*n, INPUT_SIZE], dtype=np.float32)
    
    # Dictionary mapping ordinally encoded sign to corresponding sample indices
    CLASS2IDXS = {}
    for i in range(NUM_CLASSES):
        CLASS2IDXS[i] = np.argwhere(y == i).squeeze().astype(np.int32)
            
    while True:
        # Fill batch arrays
        for i in range(NUM_CLASSES):
            idxs = np.random.choice(CLASS2IDXS[i], n)
            X_batch[i*n:(i+1)*n] = X[idxs]
            non_empty_frame_idxs_batch[i*n:(i+1)*n] = NON_EMPTY_FRAME_IDXS[idxs]
        
        yield { 'frames': X_batch, 'non_empty_frame_idxs': non_empty_frame_idxs_batch }, y_batch

# %%
dummy_dataset = get_train_batch_all_signs(X_train, y_train, NON_EMPTY_FRAME_IDXS_TRAIN)
X_batch, y_batch = next(dummy_dataset)

for k, v in X_batch.items():
    print(f'{k} shape: {v.shape}, dtype: {v.dtype}')

# Batch shape/dtype
print(f'y_batch shape: {y_batch.shape}, dtype: {y_batch.dtype}')
# Verify each batch contains each sign exactly N times
display(pd.Series(y_batch).value_counts().to_frame('Counts'))
# Out:
# frames shape: (750, 64, 66, 3), dtype: float32
# non_empty_frame_idxs shape: (750, 64), dtype: float32
# y_batch shape: (750,), dtype: int64
#      Counts
# 0         3
# 171       3
# 158       3
# 159       3
# 160       3
# ..      ...
# 88        3
# 89        3
# 90        3
# 91        3
# 249       3
#
# [250 rows x 1 columns]

# %%
# Epsilon value for layer normalisation
LAYER_NORM_EPS = 1e-6

# Dense layer units for landmarks
LIPS_UNITS = 384
HANDS_UNITS = 384
POSE_UNITS = 384
# final embedding and transformer embedding size
UNITS = 512

# Transformer
NUM_BLOCKS = 2 # 2 to 1
MLP_RATIO = 4

# Dropout
EMBEDDING_DROPOUT = 0.00
MLP_DROPOUT_RATIO = 0.2
CLASSIFIER_DROPOUT_RATIO = 0.1

# Initiailizers
INIT_HE_UNIFORM = tf.keras.initializers.he_uniform
INIT_GLOROT_UNIFORM = tf.keras.initializers.glorot_uniform
INIT_ZEROS = tf.keras.initializers.constant(0.0)
# Activations
GELU = tf.keras.activations.gelu

print(f'UNITS: {UNITS}')
# Out:
# UNITS: 512

# %%
# based on: https://stackoverflow.com/questions/67342988/verifying-the-implementation-of-multihead-attention-in-transformer
# replaced softmax with softmax layer to support masked softmax
def scaled_dot_product(q,k,v, softmax, attention_mask):
    #calculates Q . K(transpose)
    qkt = tf.matmul(q,k,transpose_b=True)
    #caculates scaling factor
    dk = tf.math.sqrt(tf.cast(q.shape[-1],dtype=tf.float32))
    scaled_qkt = qkt/dk
    softmax = softmax(scaled_qkt, mask=attention_mask)
    
    z = tf.matmul(softmax,v)
    #shape: (m,Tx,depth), same shape as q,k,v
    return z

class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self,d_model,num_of_heads):
        super(MultiHeadAttention,self).__init__()
        self.d_model = d_model
        self.num_of_heads = num_of_heads
        self.depth = d_model//num_of_heads
        self.wq = [tf.keras.layers.Dense(self.depth) for i in range(num_of_heads)]
        self.wk = [tf.keras.layers.Dense(self.depth) for i in range(num_of_heads)]
        self.wv = [tf.keras.layers.Dense(self.depth) for i in range(num_of_heads)]
        self.wo = tf.keras.layers.Dense(d_model)
        self.softmax = tf.keras.layers.Softmax()
        
    def call(self,x, attention_mask):
        
        multi_attn = []
        for i in range(self.num_of_heads):
            Q = self.wq[i](x)
            K = self.wk[i](x)
            V = self.wv[i](x)
            multi_attn.append(scaled_dot_product(Q,K,V, self.softmax, attention_mask))
            
        multi_head = tf.concat(multi_attn,axis=-1)
        multi_head_attention = self.wo(multi_head)
        return multi_head_attention

# %%
# Full Transformer
class Transformer(tf.keras.Model):
    def __init__(self, num_blocks):
        super(Transformer, self).__init__(name='transformer')
        self.num_blocks = num_blocks
    
    def build(self, input_shape):
        self.ln_1s = []
        self.mhas = []
        self.ln_2s = []
        self.mlps = []
        # Make Transformer Blocks
        for i in range(self.num_blocks):
            # Multi Head Attention
            self.mhas.append(MultiHeadAttention(UNITS, 8)) #8 to 4
             # Multi Layer Perception
            self.mlps.append(tf.keras.Sequential([
                tf.keras.layers.Dense(UNITS * MLP_RATIO, activation=GELU, kernel_initializer=INIT_GLOROT_UNIFORM),
                tf.keras.layers.Dropout(MLP_DROPOUT_RATIO),
                tf.keras.layers.Dense(UNITS, kernel_initializer=INIT_HE_UNIFORM),
            ]))
        
    def call(self, x, attention_mask):
        # Iterate input over transformer blocks
        for mha, mlp in zip(self.mhas, self.mlps):
            x = x + mha(x, attention_mask)
            x = x + mlp(x)
    
        return x

# %%
class LandmarkEmbedding(tf.keras.Model):
    def __init__(self, units, name):
        super(LandmarkEmbedding, self).__init__(name=f'{name}_embedding')
        self.units = units
        
    def build(self, input_shape):
        # Embedding for missing landmark in frame, initizlied with zeros
        self.empty_embedding = self.add_weight(
            name=f'{self.name}_empty_embedding',
            shape=[self.units],
            initializer=INIT_ZEROS,
        )
        # Embedding
        self.dense = tf.keras.Sequential([
            tf.keras.layers.Dense(self.units, name=f'{self.name}_dense_1', use_bias=False, kernel_initializer=INIT_GLOROT_UNIFORM),
            tf.keras.layers.Activation(GELU),
            tf.keras.layers.Dense(self.units, name=f'{self.name}_dense_2', use_bias=False, kernel_initializer=INIT_HE_UNIFORM),
        ], name=f'{self.name}_dense')

    def call(self, x):
        return tf.where(
                # Checks whether landmark is missing in frame
                tf.reduce_sum(x, axis=2, keepdims=True) == 0,
                # If so, the empty embedding is used
                self.empty_embedding,
                # Otherwise the landmark data is embedded
                self.dense(x),
            )

# %%
class Embedding(tf.keras.Model):
    def __init__(self):
        super(Embedding, self).__init__()
        
    def get_diffs(self, l):
        S = l.shape[2]
        other = tf.expand_dims(l, 3)
        other = tf.repeat(other, S, axis=3)
        other = tf.transpose(other, [0,1,3,2])
        diffs = tf.expand_dims(l, 3) - other
        diffs = tf.reshape(diffs, [-1, INPUT_SIZE, S*S])
        return diffs

    def build(self, input_shape):
        # Positional Embedding, initialized with zeros
        self.positional_embedding = tf.keras.layers.Embedding(INPUT_SIZE+1, UNITS, embeddings_initializer=INIT_ZEROS)
        # Embedding layer for Landmarks
        self.lips_embedding = LandmarkEmbedding(LIPS_UNITS, 'lips')
        self.left_hand_embedding = LandmarkEmbedding(HANDS_UNITS, 'left_hand')
        self.pose_embedding = LandmarkEmbedding(POSE_UNITS, 'pose')
        # Landmark Weights
        self.landmark_weights = tf.Variable(tf.zeros([3], dtype=tf.float32), name='landmark_weights')
        # Fully Connected Layers for combined landmarks
        self.fc = tf.keras.Sequential([
            tf.keras.layers.Dense(UNITS, name='fully_connected_1', use_bias=False, kernel_initializer=INIT_GLOROT_UNIFORM),
            tf.keras.layers.Activation(GELU),
            tf.keras.layers.Dense(UNITS, name='fully_connected_2', use_bias=False, kernel_initializer=INIT_HE_UNIFORM),
        ], name='fc')


    def call(self, lips0, left_hand0, pose0, non_empty_frame_idxs, training=False):
        # Lips
        lips_embedding = self.lips_embedding(lips0)
        # Left Hand
        left_hand_embedding = self.left_hand_embedding(left_hand0)
        # Pose
        pose_embedding = self.pose_embedding(pose0)
        # Merge Embeddings of all landmarks with mean pooling
        x = tf.stack((
            lips_embedding, left_hand_embedding, pose_embedding,
        ), axis=3)
        x = x * tf.nn.softmax(self.landmark_weights)
        x = tf.reduce_sum(x, axis=3)
        # Fully Connected Layers
        x = self.fc(x)
        # Add Positional Embedding
        max_frame_idxs = tf.clip_by_value(
                tf.reduce_max(non_empty_frame_idxs, axis=1, keepdims=True),
                1,
                np.PINF,
            )
        normalised_non_empty_frame_idxs = tf.where(
            tf.math.equal(non_empty_frame_idxs, -1.0),
            INPUT_SIZE,
            tf.cast(
                non_empty_frame_idxs / max_frame_idxs * INPUT_SIZE,
                tf.int32,
            ),
        )
        x = x + self.positional_embedding(normalised_non_empty_frame_idxs)
        
        return x

# %%
# Not used, adds random X/y translation to input on samples level
class Augmentation(tf.keras.layers.Layer):
    def __init__(self, noise_std):
        super(Augmentation, self).__init__()
        self.noise_std = noise_std
    
    def add_noise(self, t):
        B = tf.shape(t)[0]
        return tf.where(
            t == 0.0,
            0.0,
            t + tf.random.normal([B,1,1,tf.shape(t)[3]], 0, self.noise_std),
        )
    
    def call(self, lips0, left_hand0, pose0, training=False):
        if training:
            # Lips
            lips0 = self.add_noise(lips0)
            # Left Hand
            left_hand0 = self.add_noise(left_hand0)
            # Pose
            pose0 = self.add_noise(pose0)
        
        return lips0, left_hand0, pose0

# %%
# source:: https://stackoverflow.com/questions/60689185/label-smoothing-for-sparse-categorical-crossentropy
def scce_with_ls(y_true, y_pred):
    # One Hot Encode Sparsely Encoded Target Sign
    y_true = tf.cast(y_true, tf.int32)
    y_true = tf.one_hot(y_true, NUM_CLASSES, axis=1)
    y_true = tf.squeeze(y_true, axis=2)
    # Categorical Crossentropy with native label smoothing support
    return tf.keras.losses.categorical_crossentropy(y_true, y_pred, label_smoothing=0.25) # 0.25 to 0.75

# %%
def get_model():
    # Inputs
    frames = tf.keras.layers.Input([INPUT_SIZE, N_COLS, N_DIMS], dtype=tf.float32, name='frames')
    non_empty_frame_idxs = tf.keras.layers.Input([INPUT_SIZE], dtype=tf.float32, name='non_empty_frame_idxs')
    # Padding Mask
    mask0 = tf.cast(tf.math.not_equal(non_empty_frame_idxs, -1), tf.float32)
    mask0 = tf.expand_dims(mask0, axis=2)
    # Random Frame Masking
    mask = tf.where(
        (tf.random.uniform(tf.shape(mask0)) > 0.25) & tf.math.not_equal(mask0, 0.0),
        1.0,
        0.0,
    )
    # Correct Samples Which are all masked now...
    mask = tf.where(
        tf.math.equal(tf.reduce_sum(mask, axis=[1,2], keepdims=True), 0.0),
        mask0,
        mask,
    )
    
    
    """
        left_hand: 468:489
        pose: 489:522
        right_hand: 522:543
    """
    x = frames
    x = tf.slice(x, [0,0,0,0], [-1,INPUT_SIZE, N_COLS, 2])
    # LIPS
    lips = tf.slice(x, [0,0,LIPS_START,0], [-1,INPUT_SIZE, 40, 2])
    lips = tf.where(
            tf.math.equal(lips, 0.0),
            0.0,
            (lips - LIPS_MEAN) / LIPS_STD,
        )
    # LEFT HAND
    left_hand = tf.slice(x, [0,0,40,0], [-1,INPUT_SIZE, 21, 2])
    left_hand = tf.where(
            tf.math.equal(left_hand, 0.0),
            0.0,
            (left_hand - LEFT_HANDS_MEAN) / LEFT_HANDS_STD,
        )
    # POSE
    pose = tf.slice(x, [0,0,61,0], [-1,INPUT_SIZE, 5, 2])
    pose = tf.where(
            tf.math.equal(pose, 0.0),
            0.0,
            (pose - POSE_MEAN) / POSE_STD,
        )
    
    # Flatten
    lips = tf.reshape(lips, [-1, INPUT_SIZE, 40*2])
    left_hand = tf.reshape(left_hand, [-1, INPUT_SIZE, 21*2])
    pose = tf.reshape(pose, [-1, INPUT_SIZE, 5*2])
        
    # Embedding
    x = Embedding()(lips, left_hand, pose, non_empty_frame_idxs)
    
    # Encoder Transformer Blocks
    x = Transformer(NUM_BLOCKS)(x, mask)
    
    # Pooling
    x = tf.reduce_sum(x * mask, axis=1) / tf.reduce_sum(mask, axis=1)
    # Classifier Dropout
    x = tf.keras.layers.Dropout(CLASSIFIER_DROPOUT_RATIO)(x)
    # Classification Layer
    x = tf.keras.layers.Dense(NUM_CLASSES, activation=tf.keras.activations.softmax, kernel_initializer=INIT_GLOROT_UNIFORM)(x)
    
    outputs = x
    
    # Create Tensorflow Model
    model = tf.keras.models.Model(inputs=[frames, non_empty_frame_idxs], outputs=outputs)
    
    # Sparse Categorical Cross Entropy With Label Smoothing
    loss = scce_with_ls
    
    # Adam Optimizer with weight decay
    optimizer = tfa.optimizers.AdamW(learning_rate=LR_MAX, weight_decay=1e-5, clipnorm=1.0)
    
    # TopK Metrics
    metrics = [
        tf.keras.metrics.SparseCategoricalAccuracy(name='acc'),
        tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5, name='top_5_acc'),
        tf.keras.metrics.SparseTopKCategoricalAccuracy(k=10, name='top_10_acc'),
    ]
    
    model.compile(loss=loss, optimizer=optimizer, metrics=metrics)
    
    return model

# %%
tf.keras.backend.clear_session()

model = get_model()

# %%
# Plot model summary
model.summary(expand_nested=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  non_empty_frame_idxs (InputLay  [(None, 64)]        0           []
#  er)
#
#  tf.math.not_equal (TFOpLambda)  (None, 64)          0           ['non_empty_frame_idxs[0][0]']
#
#  tf.cast (TFOpLambda)           (None, 64)           0           ['tf.math.not_equal[0][0]']
#
#  tf.expand_dims (TFOpLambda)    (None, 64, 1)        0           ['tf.cast[0][0]']
#
#  frames (InputLayer)            [(None, 64, 66, 3)]  0           []
#
#  tf.compat.v1.shape (TFOpLambda  (3,)                0           ['tf.expand_dims[0][0]']
#  )
#
#  tf.slice (TFOpLambda)          (None, 64, 66, 2)    0           ['frames[0][0]']
#
#  tf.random.uniform (TFOpLambda)  (None, 64, 1)       0           ['tf.compat.v1.shape[0][0]']
#
#  tf.slice_1 (TFOpLambda)        (None, 64, 40, 2)    0           ['tf.slice[0][0]']
#
#  tf.slice_2 (TFOpLambda)        (None, 64, 21, 2)    0           ['tf.slice[0][0]']
#
#  tf.slice_3 (TFOpLambda)        (None, 64, 5, 2)     0           ['tf.slice[0][0]']
#
#  tf.math.greater (TFOpLambda)   (None, 64, 1)        0           ['tf.random.uniform[0][0]']
#
#  tf.math.not_equal_1 (TFOpLambd  (None, 64, 1)       0           ['tf.expand_dims[0][0]']
#  a)
#
#  tf.math.subtract (TFOpLambda)  (None, 64, 40, 2)    0           ['tf.slice_1[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 64, 21, 2)   0           ['tf.slice_2[0][0]']
#  )
#
#  tf.math.subtract_2 (TFOpLambda  (None, 64, 5, 2)    0           ['tf.slice_3[0][0]']
#  )
#
#  tf.math.logical_and (TFOpLambd  (None, 64, 1)       0           ['tf.math.greater[0][0]',
#  a)                                                               'tf.math.not_equal_1[0][0]']
#
#  tf.math.equal_1 (TFOpLambda)   (None, 64, 40, 2)    0           ['tf.slice_1[0][0]']
#
#  tf.math.truediv (TFOpLambda)   (None, 64, 40, 2)    0           ['tf.math.subtract[0][0]']
#
#  tf.math.equal_2 (TFOpLambda)   (None, 64, 21, 2)    0           ['tf.slice_2[0][0]']
#
#  tf.math.truediv_1 (TFOpLambda)  (None, 64, 21, 2)   0           ['tf.math.subtract_1[0][0]']
#
#  tf.math.equal_3 (TFOpLambda)   (None, 64, 5, 2)     0           ['tf.slice_3[0][0]']
#
#  tf.math.truediv_2 (TFOpLambda)  (None, 64, 5, 2)    0           ['tf.math.subtract_2[0][0]']
#
#  tf.where (TFOpLambda)          (None, 64, 1)        0           ['tf.math.logical_and[0][0]']
#
#  tf.where_2 (TFOpLambda)        (None, 64, 40, 2)    0           ['tf.math.equal_1[0][0]',
#                                                                   'tf.math.truediv[0][0]']
#
#  tf.where_3 (TFOpLambda)        (None, 64, 21, 2)    0           ['tf.math.equal_2[0][0]',
#                                                                   'tf.math.truediv_1[0][0]']
#
#  tf.where_4 (TFOpLambda)        (None, 64, 5, 2)     0           ['tf.math.equal_3[0][0]',
#                                                                   'tf.math.truediv_2[0][0]']
#
#  tf.math.reduce_sum (TFOpLambda  (None, 1, 1)        0           ['tf.where[0][0]']
#  )
#
#  tf.reshape (TFOpLambda)        (None, 64, 80)       0           ['tf.where_2[0][0]']
#
#  tf.reshape_1 (TFOpLambda)      (None, 64, 42)       0           ['tf.where_3[0][0]']
#
#  tf.reshape_2 (TFOpLambda)      (None, 64, 10)       0           ['tf.where_4[0][0]']
#
#  tf.math.equal (TFOpLambda)     (None, 1, 1)         0           ['tf.math.reduce_sum[0][0]']
#
#  embedding (Embedding)          (None, 64, 512)      986243      ['tf.reshape[0][0]',
#                                                                   'tf.reshape_1[0][0]',
#                                                                   'tf.reshape_2[0][0]',
#                                                                   'non_empty_frame_idxs[0][0]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | embedding (Embedding)        multiple             33280       []                               |
# |                                                                                                |
# | lips_embedding (LandmarkEmbedd  multiple          178560      []                               |
# | ing)                                                                                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || lips_embedding_dense (Sequenti  (None, 64, 384)  178176     []                               ||
# || al)                                                                                          ||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| lips_embedding_dense_1 (Dense)  (None, 64, 384)  30720    []                               |||
# |||                                                                                            |||
# ||| activation_1 (Activation)  (None, 64, 384)    0           []                               |||
# |||                                                                                            |||
# ||| lips_embedding_dense_2 (Dense)  (None, 64, 384)  147456   []                               |||
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | left_hand_embedding (LandmarkE  multiple          163968      []                               |
# | mbedding)                                                                                      |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || left_hand_embedding_dense (Seq  (None, 64, 384)  163584     []                               ||
# || uential)                                                                                     ||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| left_hand_embedding_dense_1 (D  (None, 64, 384)  16128    []                               |||
# ||| ense)                                                                                      |||
# |||                                                                                            |||
# ||| activation_2 (Activation)  (None, 64, 384)    0           []                               |||
# |||                                                                                            |||
# ||| left_hand_embedding_dense_2 (D  (None, 64, 384)  147456   []                               |||
# ||| ense)                                                                                      |||
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | pose_embedding (LandmarkEmbedd  multiple          151680      []                               |
# | ing)                                                                                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || pose_embedding_dense (Sequenti  (None, 64, 384)  151296     []                               ||
# || al)                                                                                          ||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| pose_embedding_dense_1 (Dense)  (None, 64, 384)  3840     []                               |||
# |||                                                                                            |||
# ||| activation_3 (Activation)  (None, 64, 384)    0           []                               |||
# |||                                                                                            |||
# ||| pose_embedding_dense_2 (Dense)  (None, 64, 384)  147456   []                               |||
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | fc (Sequential)              (None, 64, 512)      458752      []                               |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || fully_connected_1 (Dense)  (None, 64, 512)      196608      []                               ||
# ||                                                                                              ||
# || activation (Activation)    (None, 64, 512)      0           []                               ||
# ||                                                                                              ||
# || fully_connected_2 (Dense)  (None, 64, 512)      262144      []                               ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  tf.where_1 (TFOpLambda)        (None, 64, 1)        0           ['tf.math.equal[0][0]',
#                                                                   'tf.expand_dims[0][0]',
#                                                                   'tf.where[0][0]']
#
#  transformer (Transformer)      (None, 64, 512)      6300672     ['embedding[0][0]',
#                                                                   'tf.where_1[0][0]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | multi_head_attention (MultiHea  multiple          1050624     []                               |
# | dAttention)                                                                                    |
# |                                                                                                |
# | multi_head_attention_1 (MultiH  multiple          1050624     []                               |
# | eadAttention)                                                                                  |
# |                                                                                                |
# | sequential (Sequential)      (None, 64, 512)      2099712     []                               |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || dense_25 (Dense)           (None, 64, 2048)     1050624     []                               ||
# ||                                                                                              ||
# || dropout (Dropout)          (None, 64, 2048)     0           []                               ||
# ||                                                                                              ||
# || dense_26 (Dense)           (None, 64, 512)      1049088     []                               ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_1 (Sequential)    (None, 64, 512)      2099712     []                               |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || dense_52 (Dense)           (None, 64, 2048)     1050624     []                               ||
# ||                                                                                              ||
# || dropout_1 (Dropout)        (None, 64, 2048)     0           []                               ||
# ||                                                                                              ||
# || dense_53 (Dense)           (None, 64, 512)      1049088     []                               ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  tf.math.multiply (TFOpLambda)  (None, 64, 512)      0           ['transformer[0][0]',
#                                                                   'tf.where_1[0][0]']
#
#  tf.math.reduce_sum_1 (TFOpLamb  (None, 512)         0           ['tf.math.multiply[0][0]']
#  da)
#
#  tf.math.reduce_sum_2 (TFOpLamb  (None, 1)           0           ['tf.where_1[0][0]']
#  da)
#
#  tf.math.truediv_3 (TFOpLambda)  (None, 512)         0           ['tf.math.reduce_sum_1[0][0]',
#                                                                   'tf.math.reduce_sum_2[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['tf.math.truediv_3[0][0]']
#
#  dense (Dense)                  (None, 250)          128250      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 7,415,165
# Trainable params: 7,415,165
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True, show_dtype=True, show_layer_names=True, expand_nested=True, show_layer_activations=True)

# %%
if not PREPROCESS_DATA and TRAIN_MODEL:
    y_pred = model.predict_on_batch(X_batch).flatten()

    print(f'# NaN Values In Prediction: {np.isnan(y_pred).sum()}')
# Out:
# # NaN Values In Prediction: 0

# %%
def lrfn(current_step, num_warmup_steps, lr_max, num_cycles=0.5,num_training_steps=N_EPOCHS):
    
    if current_step < num_warmup_steps:
#         if WARMUP_METHOD == 'log':
#             return lr_max * 0.10 ** (num_warmup_steps - current_step)
#         else:
        #return lr_max * 0.10 ** (num_warmup_steps - current_step)
        return lr_max * 2 ** -(num_warmup_steps - current_step)
    else:
        progress = float(current_step - num_warmup_steps) / float(max(1, num_training_steps - num_warmup_steps))

        return max(0.0, 0.5 * (1.0 + math.cos(math.pi * float(num_cycles) * 2.0 * progress))) * lr_max

# %%
def plot_lr_schedule(lr_schedule, epochs):
    fig = plt.figure(figsize=(20, 10))
    plt.plot([None] + lr_schedule + [None])
    # X Labels
    x = np.arange(1, epochs + 1)
    x_axis_labels = [i if epochs <= 40 or i % 5 == 0 or i == 1 else None for i in range(1, epochs + 1)]
    plt.xlim([1, epochs])
    plt.xticks(x, x_axis_labels) # set tick step to 1 and let x axis start at 1
    
    # Increase y-limit for better readability
    plt.ylim([0, max(lr_schedule) * 1.1])
    
    # Title
    schedule_info = f'start: {lr_schedule[0]:.1E}, max: {max(lr_schedule):.1E}, final: {lr_schedule[-1]:.1E}'
    plt.title(f'Step Learning Rate Schedule, {schedule_info}', size=18, pad=12)
    
    # Plot Learning Rates
    for x, val in enumerate(lr_schedule):
        if epochs <= 40 or x % 5 == 0 or x is epochs - 1:
            if x < len(lr_schedule) - 1:
                if lr_schedule[x - 1] < val:
                    ha = 'right'
                else:
                    ha = 'left'
            elif x == 0:
                ha = 'right'
            else:
                ha = 'left'
            plt.plot(x + 1, val, 'o', color='black');
            offset_y = (max(lr_schedule) - min(lr_schedule)) * 0.02
            plt.annotate(f'{val:.1E}', xy=(x + 1, val + offset_y), size=12, ha=ha)
    
    plt.xlabel('Epoch', size=16, labelpad=5)
    plt.ylabel('Learning Rate', size=16, labelpad=5)
    plt.grid()
    plt.show()

# Learning rate for encoder
LR_SCHEDULE = [lrfn(step, num_warmup_steps=N_WARMUP_EPOCHS, lr_max=LR_MAX, num_cycles=0.50) for step in range(N_EPOCHS)]
# Plot Learning Rate Schedule
plot_lr_schedule(LR_SCHEDULE, epochs=N_EPOCHS)
# Learning Rate Callback
lr_callback = tf.keras.callbacks.LearningRateScheduler(lambda step: LR_SCHEDULE[step], verbose=1)

# %%
# Custom callback to update weight decay with learning rate
class WeightDecayCallback(tf.keras.callbacks.Callback):
    def __init__(self, wd_ratio=WD_RATIO):
        self.step_counter = 0
        self.wd_ratio = wd_ratio
    
    def on_epoch_begin(self, epoch, logs=None):
        model.optimizer.weight_decay = model.optimizer.learning_rate * self.wd_ratio
        print(f'learning rate: {model.optimizer.learning_rate.numpy():.2e}, weight decay: {model.optimizer.weight_decay.numpy():.2e}')

# %%
# %%timeit -n 100
if TRAIN_MODEL:
    # Verify model prediction is <<<100ms
    model.predict_on_batch({ 'frames': X_train[:1], 'non_empty_frame_idxs': NON_EMPTY_FRAME_IDXS_TRAIN[:1] })
    pass
# Out:
# 18.2 ms ± 5.46 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
if USE_VAL:
    # Verify Validation Dataset Covers All Signs
    print(f'# Unique Signs in Validation Set: {pd.Series(y_val).nunique()}')
    # Value Counts
    display(pd.Series(y_val).value_counts().to_frame('Count').iloc[[1,2,3,-3,-2,-1]])

# %%
# Sanity Check
if TRAIN_MODEL and USE_VAL:
    _ = model.evaluate(*validation_data, verbose=2)

# %%
if TRAIN_MODEL:
    # Clear all models in GPU
    tf.keras.backend.clear_session()

    # Get new fresh model
    model = get_model()
    
    # Sanity Check
    model.summary()

    # Actual Training
    history = model.fit(
            x=get_train_batch_all_signs(X_train, y_train, NON_EMPTY_FRAME_IDXS_TRAIN),
            steps_per_epoch=len(X_train) // (NUM_CLASSES * BATCH_ALL_SIGNS_N),
            epochs=N_EPOCHS,
            # Only used for validation data since training data is a generator
            batch_size=BATCH_SIZE,
            validation_data=validation_data,
            callbacks=[
                lr_callback,
                WeightDecayCallback(),
            ],
            verbose = VERBOSE,
        )
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  non_empty_frame_idxs (InputLay  [(None, 64)]        0           []
#  er)
#
#  tf.math.not_equal (TFOpLambda)  (None, 64)          0           ['non_empty_frame_idxs[0][0]']
#
#  tf.cast (TFOpLambda)           (None, 64)           0           ['tf.math.not_equal[0][0]']
#
#  tf.expand_dims (TFOpLambda)    (None, 64, 1)        0           ['tf.cast[0][0]']
#
#  frames (InputLayer)            [(None, 64, 66, 3)]  0           []
#
#  tf.compat.v1.shape (TFOpLambda  (3,)                0           ['tf.expand_dims[0][0]']
#  )
#
#  tf.slice (TFOpLambda)          (None, 64, 66, 2)    0           ['frames[0][0]']
#
#  tf.random.uniform (TFOpLambda)  (None, 64, 1)       0           ['tf.compat.v1.shape[0][0]']
#
#  tf.slice_1 (TFOpLambda)        (None, 64, 40, 2)    0           ['tf.slice[0][0]']
#
#  tf.slice_2 (TFOpLambda)        (None, 64, 21, 2)    0           ['tf.slice[0][0]']
#
#  tf.slice_3 (TFOpLambda)        (None, 64, 5, 2)     0           ['tf.slice[0][0]']
#
#  tf.math.greater (TFOpLambda)   (None, 64, 1)        0           ['tf.random.uniform[0][0]']
#
#  tf.math.not_equal_1 (TFOpLambd  (None, 64, 1)       0           ['tf.expand_dims[0][0]']
#  a)
#
#  tf.math.subtract (TFOpLambda)  (None, 64, 40, 2)    0           ['tf.slice_1[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 64, 21, 2)   0           ['tf.slice_2[0][0]']
#  )
#
#  tf.math.subtract_2 (TFOpLambda  (None, 64, 5, 2)    0           ['tf.slice_3[0][0]']
#  )
#
#  tf.math.logical_and (TFOpLambd  (None, 64, 1)       0           ['tf.math.greater[0][0]',
#  a)                                                               'tf.math.not_equal_1[0][0]']
#
#  tf.math.equal_1 (TFOpLambda)   (None, 64, 40, 2)    0           ['tf.slice_1[0][0]']
#
#  tf.math.truediv (TFOpLambda)   (None, 64, 40, 2)    0           ['tf.math.subtract[0][0]']
#
#  tf.math.equal_2 (TFOpLambda)   (None, 64, 21, 2)    0           ['tf.slice_2[0][0]']
#
#  tf.math.truediv_1 (TFOpLambda)  (None, 64, 21, 2)   0           ['tf.math.subtract_1[0][0]']
#
#  tf.math.equal_3 (TFOpLambda)   (None, 64, 5, 2)     0           ['tf.slice_3[0][0]']
#
#  tf.math.truediv_2 (TFOpLambda)  (None, 64, 5, 2)    0           ['tf.math.subtract_2[0][0]']
#
#  tf.where (TFOpLambda)          (None, 64, 1)        0           ['tf.math.logical_and[0][0]']
#
#  tf.where_2 (TFOpLambda)        (None, 64, 40, 2)    0           ['tf.math.equal_1[0][0]',
#                                                                   'tf.math.truediv[0][0]']
#
#  tf.where_3 (TFOpLambda)        (None, 64, 21, 2)    0           ['tf.math.equal_2[0][0]',
#                                                                   'tf.math.truediv_1[0][0]']
#
#  tf.where_4 (TFOpLambda)        (None, 64, 5, 2)     0           ['tf.math.equal_3[0][0]',
#                                                                   'tf.math.truediv_2[0][0]']
#
#  tf.math.reduce_sum (TFOpLambda  (None, 1, 1)        0           ['tf.where[0][0]']
#  )
#
#  tf.reshape (TFOpLambda)        (None, 64, 80)       0           ['tf.where_2[0][0]']
#
#  tf.reshape_1 (TFOpLambda)      (None, 64, 42)       0           ['tf.where_3[0][0]']
#
#  tf.reshape_2 (TFOpLambda)      (None, 64, 10)       0           ['tf.where_4[0][0]']
#
#  tf.math.equal (TFOpLambda)     (None, 1, 1)         0           ['tf.math.reduce_sum[0][0]']
#
#  embedding (Embedding)          (None, 64, 512)      986243      ['tf.reshape[0][0]',
#                                                                   'tf.reshape_1[0][0]',
#                                                                   'tf.reshape_2[0][0]',
#                                                                   'non_empty_frame_idxs[0][0]']
#
#  tf.where_1 (TFOpLambda)        (None, 64, 1)        0           ['tf.math.equal[0][0]',
#                                                                   'tf.expand_dims[0][0]',
#                                                                   'tf.where[0][0]']
#
#  transformer (Transformer)      (None, 64, 512)      6300672     ['embedding[0][0]',
#                                                                   'tf.where_1[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 64, 512)      0           ['transformer[0][0]',
#                                                                   'tf.where_1[0][0]']
#
#  tf.math.reduce_sum_1 (TFOpLamb  (None, 512)         0           ['tf.math.multiply[0][0]']
#  da)
#
#  tf.math.reduce_sum_2 (TFOpLamb  (None, 1)           0           ['tf.where_1[0][0]']
#  da)
#
#  tf.math.truediv_3 (TFOpLambda)  (None, 512)         0           ['tf.math.reduce_sum_1[0][0]',
#                                                                   'tf.math.reduce_sum_2[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['tf.math.truediv_3[0][0]']
#
#  dense (Dense)                  (None, 250)          128250      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 7,415,165
# Trainable params: 7,415,165
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# Epoch 1: LearningRateScheduler setting learning rate to 8.881784197001253e-19.
# learning rate: 8.88e-19, weight decay: 4.44e-20
# Epoch 1/250
# 125/125 - 77s - loss: 5.5789 - acc: 0.0034 - top_5_acc: 0.0187 - top_10_acc: 0.0380 - lr: 8.8818e-19 - 77s/epoch - 616ms/step
#
# Epoch 2: LearningRateScheduler setting learning rate to 1.7763568394002505e-18.
# learning rate: 1.78e-18, weight decay: 8.88e-20
# Epoch 2/250
# 125/125 - 65s - loss: 5.5801 - acc: 0.0032 - top_5_acc: 0.0185 - top_10_acc: 0.0381 - lr: 1.7764e-18 - 65s/epoch - 519ms/step
#
# Epoch 3: LearningRateScheduler setting learning rate to 3.552713678800501e-18.
# learning rate: 3.55e-18, weight decay: 1.78e-19
# Epoch 3/250
# 125/125 - 65s - loss: 5.5794 - acc: 0.0036 - top_5_acc: 0.0192 - top_10_acc: 0.0386 - lr: 3.5527e-18 - 65s/epoch - 519ms/step
#
# Epoch 4: LearningRateScheduler setting learning rate to 7.105427357601002e-18.
# learning rate: 7.11e-18, weight decay: 3.55e-19
# Epoch 4/250
# 125/125 - 65s - loss: 5.5806 - acc: 0.0038 - top_5_acc: 0.0186 - top_10_acc: 0.0378 - lr: 7.1054e-18 - 65s/epoch - 518ms/step
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.4210854715202004e-17.
# learning rate: 1.42e-17, weight decay: 7.11e-19
# Epoch 5/250
# 125/125 - 65s - loss: 5.5787 - acc: 0.0035 - top_5_acc: 0.0181 - top_10_acc: 0.0382 - lr: 1.4211e-17 - 65s/epoch - 518ms/step
#
# Epoch 6: LearningRateScheduler setting learning rate to 2.842170943040401e-17.
# learning rate: 2.84e-17, weight decay: 1.42e-18
# Epoch 6/250
# 125/125 - 65s - loss: 5.5788 - acc: 0.0033 - top_5_acc: 0.0188 - top_10_acc: 0.0385 - lr: 2.8422e-17 - 65s/epoch - 518ms/step
#
# Epoch 7: LearningRateScheduler setting learning rate to 5.684341886080802e-17.
# learning rate: 5.68e-17, weight decay: 2.84e-18
# Epoch 7/250
# 125/125 - 65s - loss: 5.5777 - acc: 0.0038 - top_5_acc: 0.0194 - top_10_acc: 0.0382 - lr: 5.6843e-17 - 65s/epoch - 519ms/step
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.1368683772161603e-16.
# learning rate: 1.14e-16, weight decay: 5.68e-18
# Epoch 8/250
# 125/125 - 65s - loss: 5.5778 - acc: 0.0036 - top_5_acc: 0.0188 - top_10_acc: 0.0383 - lr: 1.1369e-16 - 65s/epoch - 519ms/step
#
# Epoch 9: LearningRateScheduler setting learning rate to 2.2737367544323206e-16.
# learning rate: 2.27e-16, weight decay: 1.14e-17
# Epoch 9/250
# 125/125 - 65s - loss: 5.5799 - acc: 0.0033 - top_5_acc: 0.0184 - top_10_acc: 0.0377 - lr: 2.2737e-16 - 65s/epoch - 519ms/step
#
# Epoch 10: LearningRateScheduler setting learning rate to 4.547473508864641e-16.
# learning rate: 4.55e-16, weight decay: 2.27e-17
# Epoch 10/250
# 125/125 - 65s - loss: 5.5792 - acc: 0.0033 - top_5_acc: 0.0190 - top_10_acc: 0.0382 - lr: 4.5475e-16 - 65s/epoch - 518ms/step
#
# Epoch 11: LearningRateScheduler setting learning rate to 9.094947017729283e-16.
# learning rate: 9.09e-16, weight decay: 4.55e-17
# Epoch 11/250
# 125/125 - 65s - loss: 5.5795 - acc: 0.0035 - top_5_acc: 0.0184 - top_10_acc: 0.0369 - lr: 9.0949e-16 - 65s/epoch - 519ms/step
#
# Epoch 12: LearningRateScheduler setting learning rate to 1.8189894035458565e-15.
# learning rate: 1.82e-15, weight decay: 9.09e-17
# Epoch 12/250
# 125/125 - 65s - loss: 5.5785 - acc: 0.0037 - top_5_acc: 0.0190 - top_10_acc: 0.0376 - lr: 1.8190e-15 - 65s/epoch - 518ms/step
#
# Epoch 13: LearningRateScheduler setting learning rate to 3.637978807091713e-15.
# learning rate: 3.64e-15, weight decay: 1.82e-16
# Epoch 13/250
# 125/125 - 65s - loss: 5.5787 - acc: 0.0034 - top_5_acc: 0.0193 - top_10_acc: 0.0374 - lr: 3.6380e-15 - 65s/epoch - 519ms/step
#
# Epoch 14: LearningRateScheduler setting learning rate to 7.275957614183426e-15.
# learning rate: 7.28e-15, weight decay: 3.64e-16
# Epoch 14/250
# 125/125 - 65s - loss: 5.5797 - acc: 0.0034 - top_5_acc: 0.0180 - top_10_acc: 0.0375 - lr: 7.2760e-15 - 65s/epoch - 519ms/step
#
# Epoch 15: LearningRateScheduler setting learning rate to 1.4551915228366852e-14.
# learning rate: 1.46e-14, weight decay: 7.28e-16
# Epoch 15/250
# 125/125 - 65s - loss: 5.5804 - acc: 0.0033 - top_5_acc: 0.0181 - top_10_acc: 0.0368 - lr: 1.4552e-14 - 65s/epoch - 519ms/step
#
# Epoch 16: LearningRateScheduler setting learning rate to 2.9103830456733704e-14.
# learning rate: 2.91e-14, weight decay: 1.46e-15
# Epoch 16/250
# 125/125 - 65s - loss: 5.5803 - acc: 0.0032 - top_5_acc: 0.0189 - top_10_acc: 0.0375 - lr: 2.9104e-14 - 65s/epoch - 518ms/step
#
# Epoch 17: LearningRateScheduler setting learning rate to 5.820766091346741e-14.
# learning rate: 5.82e-14, weight decay: 2.91e-15
# Epoch 17/250
# 125/125 - 65s - loss: 5.5795 - acc: 0.0035 - top_5_acc: 0.0184 - top_10_acc: 0.0380 - lr: 5.8208e-14 - 65s/epoch - 518ms/step
#
# Epoch 18: LearningRateScheduler setting learning rate to 1.1641532182693482e-13.
# learning rate: 1.16e-13, weight decay: 5.82e-15
# Epoch 18/250
# 125/125 - 65s - loss: 5.5791 - acc: 0.0031 - top_5_acc: 0.0183 - top_10_acc: 0.0378 - lr: 1.1642e-13 - 65s/epoch - 519ms/step
#
# Epoch 19: LearningRateScheduler setting learning rate to 2.3283064365386963e-13.
# learning rate: 2.33e-13, weight decay: 1.16e-14
# Epoch 19/250
# 125/125 - 65s - loss: 5.5778 - acc: 0.0030 - top_5_acc: 0.0185 - top_10_acc: 0.0379 - lr: 2.3283e-13 - 65s/epoch - 518ms/step
#
# Epoch 20: LearningRateScheduler setting learning rate to 4.656612873077393e-13.
# learning rate: 4.66e-13, weight decay: 2.33e-14
# Epoch 20/250
# 125/125 - 65s - loss: 5.5794 - acc: 0.0035 - top_5_acc: 0.0188 - top_10_acc: 0.0379 - lr: 4.6566e-13 - 65s/epoch - 519ms/step
#
# Epoch 21: LearningRateScheduler setting learning rate to 9.313225746154785e-13.
# learning rate: 9.31e-13, weight decay: 4.66e-14
# Epoch 21/250
# 125/125 - 65s - loss: 5.5794 - acc: 0.0036 - top_5_acc: 0.0191 - top_10_acc: 0.0385 - lr: 9.3132e-13 - 65s/epoch - 518ms/step
#
# Epoch 22: LearningRateScheduler setting learning rate to 1.862645149230957e-12.
# learning rate: 1.86e-12, weight decay: 9.31e-14
# Epoch 22/250
# 125/125 - 65s - loss: 5.5794 - acc: 0.0033 - top_5_acc: 0.0178 - top_10_acc: 0.0374 - lr: 1.8626e-12 - 65s/epoch - 518ms/step
#
# Epoch 23: LearningRateScheduler setting learning rate to 3.725290298461914e-12.
# learning rate: 3.73e-12, weight decay: 1.86e-13
# Epoch 23/250
# 125/125 - 65s - loss: 5.5794 - acc: 0.0035 - top_5_acc: 0.0186 - top_10_acc: 0.0374 - lr: 3.7253e-12 - 65s/epoch - 519ms/step
#
# Epoch 24: LearningRateScheduler setting learning rate to 7.450580596923828e-12.
# learning rate: 7.45e-12, weight decay: 3.73e-13
# Epoch 24/250
# 125/125 - 65s - loss: 5.5802 - acc: 0.0035 - top_5_acc: 0.0184 - top_10_acc: 0.0377 - lr: 7.4506e-12 - 65s/epoch - 519ms/step
#
# Epoch 25: LearningRateScheduler setting learning rate to 1.4901161193847657e-11.
# learning rate: 1.49e-11, weight decay: 7.45e-13
# Epoch 25/250
# 125/125 - 65s - loss: 5.5778 - acc: 0.0036 - top_5_acc: 0.0193 - top_10_acc: 0.0376 - lr: 1.4901e-11 - 65s/epoch - 519ms/step
#
# Epoch 26: LearningRateScheduler setting learning rate to 2.980232238769531e-11.
# learning rate: 2.98e-11, weight decay: 1.49e-12
# Epoch 26/250
# 125/125 - 65s - loss: 5.5811 - acc: 0.0033 - top_5_acc: 0.0184 - top_10_acc: 0.0379 - lr: 2.9802e-11 - 65s/epoch - 519ms/step
#
# Epoch 27: LearningRateScheduler setting learning rate to 5.960464477539063e-11.
# learning rate: 5.96e-11, weight decay: 2.98e-12
# Epoch 27/250
# 125/125 - 65s - loss: 5.5789 - acc: 0.0033 - top_5_acc: 0.0185 - top_10_acc: 0.0371 - lr: 5.9605e-11 - 65s/epoch - 519ms/step
#
# Epoch 28: LearningRateScheduler setting learning rate to 1.1920928955078125e-10.
# learning rate: 1.19e-10, weight decay: 5.96e-12
# Epoch 28/250
# 125/125 - 65s - loss: 5.5795 - acc: 0.0034 - top_5_acc: 0.0185 - top_10_acc: 0.0380 - lr: 1.1921e-10 - 65s/epoch - 518ms/step
#
# Epoch 29: LearningRateScheduler setting learning rate to 2.384185791015625e-10.
# learning rate: 2.38e-10, weight decay: 1.19e-11
# Epoch 29/250
# 125/125 - 65s - loss: 5.5781 - acc: 0.0036 - top_5_acc: 0.0186 - top_10_acc: 0.0380 - lr: 2.3842e-10 - 65s/epoch - 518ms/step
#
# Epoch 30: LearningRateScheduler setting learning rate to 4.76837158203125e-10.
# learning rate: 4.77e-10, weight decay: 2.38e-11
# Epoch 30/250
# 125/125 - 65s - loss: 5.5791 - acc: 0.0038 - top_5_acc: 0.0193 - top_10_acc: 0.0386 - lr: 4.7684e-10 - 65s/epoch - 519ms/step
#
# Epoch 31: LearningRateScheduler setting learning rate to 9.5367431640625e-10.
# learning rate: 9.54e-10, weight decay: 4.77e-11
# Epoch 31/250
# 125/125 - 65s - loss: 5.5796 - acc: 0.0035 - top_5_acc: 0.0190 - top_10_acc: 0.0375 - lr: 9.5367e-10 - 65s/epoch - 519ms/step
#
# Epoch 32: LearningRateScheduler setting learning rate to 1.9073486328125e-09.
# learning rate: 1.91e-09, weight decay: 9.54e-11
# Epoch 32/250
# 125/125 - 65s - loss: 5.5793 - acc: 0.0030 - top_5_acc: 0.0182 - top_10_acc: 0.0378 - lr: 1.9073e-09 - 65s/epoch - 519ms/step
#
# Epoch 33: LearningRateScheduler setting learning rate to 3.814697265625e-09.
# learning rate: 3.81e-09, weight decay: 1.91e-10
# Epoch 33/250
# 125/125 - 65s - loss: 5.5788 - acc: 0.0034 - top_5_acc: 0.0180 - top_10_acc: 0.0374 - lr: 3.8147e-09 - 65s/epoch - 519ms/step
#
# Epoch 34: LearningRateScheduler setting learning rate to 7.62939453125e-09.
# learning rate: 7.63e-09, weight decay: 3.81e-10
# Epoch 34/250
# 125/125 - 65s - loss: 5.5787 - acc: 0.0036 - top_5_acc: 0.0191 - top_10_acc: 0.0386 - lr: 7.6294e-09 - 65s/epoch - 519ms/step
#
# Epoch 35: LearningRateScheduler setting learning rate to 1.52587890625e-08.
# learning rate: 1.53e-08, weight decay: 7.63e-10
# Epoch 35/250
# 125/125 - 65s - loss: 5.5775 - acc: 0.0035 - top_5_acc: 0.0192 - top_10_acc: 0.0383 - lr: 1.5259e-08 - 65s/epoch - 519ms/step
#
# Epoch 36: LearningRateScheduler setting learning rate to 3.0517578125e-08.
# learning rate: 3.05e-08, weight decay: 1.53e-09
# Epoch 36/250
# 125/125 - 65s - loss: 5.5773 - acc: 0.0034 - top_5_acc: 0.0182 - top_10_acc: 0.0378 - lr: 3.0518e-08 - 65s/epoch - 519ms/step
#
# Epoch 37: LearningRateScheduler setting learning rate to 6.103515625e-08.
# learning rate: 6.10e-08, weight decay: 3.05e-09
# Epoch 37/250
# 125/125 - 65s - loss: 5.5760 - acc: 0.0034 - top_5_acc: 0.0184 - top_10_acc: 0.0373 - lr: 6.1035e-08 - 65s/epoch - 518ms/step
#
# Epoch 38: LearningRateScheduler setting learning rate to 1.220703125e-07.
# learning rate: 1.22e-07, weight decay: 6.10e-09
# Epoch 38/250
# 125/125 - 65s - loss: 5.5719 - acc: 0.0037 - top_5_acc: 0.0202 - top_10_acc: 0.0400 - lr: 1.2207e-07 - 65s/epoch - 518ms/step
#
# Epoch 39: LearningRateScheduler setting learning rate to 2.44140625e-07.
# learning rate: 2.44e-07, weight decay: 1.22e-08
# Epoch 39/250
# 125/125 - 65s - loss: 5.5667 - acc: 0.0037 - top_5_acc: 0.0201 - top_10_acc: 0.0404 - lr: 2.4414e-07 - 65s/epoch - 519ms/step
#
# Epoch 40: LearningRateScheduler setting learning rate to 4.8828125e-07.
# learning rate: 4.88e-07, weight decay: 2.44e-08
# Epoch 40/250
# 125/125 - 65s - loss: 5.5551 - acc: 0.0042 - top_5_acc: 0.0224 - top_10_acc: 0.0450 - lr: 4.8828e-07 - 65s/epoch - 519ms/step
#
# Epoch 41: LearningRateScheduler setting learning rate to 9.765625e-07.
# learning rate: 9.77e-07, weight decay: 4.88e-08
# Epoch 41/250
# 125/125 - 65s - loss: 5.5343 - acc: 0.0056 - top_5_acc: 0.0280 - top_10_acc: 0.0560 - lr: 9.7656e-07 - 65s/epoch - 519ms/step
#
# Epoch 42: LearningRateScheduler setting learning rate to 1.953125e-06.
# learning rate: 1.95e-06, weight decay: 9.77e-08
# Epoch 42/250
# 125/125 - 65s - loss: 5.5000 - acc: 0.0097 - top_5_acc: 0.0439 - top_10_acc: 0.0792 - lr: 1.9531e-06 - 65s/epoch - 519ms/step
#
# Epoch 43: LearningRateScheduler setting learning rate to 3.90625e-06.
# learning rate: 3.91e-06, weight decay: 1.95e-07
# Epoch 43/250
# 125/125 - 65s - loss: 5.4401 - acc: 0.0166 - top_5_acc: 0.0682 - top_10_acc: 0.1178 - lr: 3.9063e-06 - 65s/epoch - 519ms/step
#
# Epoch 44: LearningRateScheduler setting learning rate to 7.8125e-06.
# learning rate: 7.81e-06, weight decay: 3.91e-07
# Epoch 44/250
# 125/125 - 65s - loss: 5.3348 - acc: 0.0286 - top_5_acc: 0.1057 - top_10_acc: 0.1775 - lr: 7.8125e-06 - 65s/epoch - 518ms/step
#
# Epoch 45: LearningRateScheduler setting learning rate to 1.5625e-05.
# learning rate: 1.56e-05, weight decay: 7.81e-07
# Epoch 45/250
# 125/125 - 65s - loss: 5.1328 - acc: 0.0609 - top_5_acc: 0.1991 - top_10_acc: 0.3075 - lr: 1.5625e-05 - 65s/epoch - 518ms/step
#
# Epoch 46: LearningRateScheduler setting learning rate to 3.125e-05.
# learning rate: 3.13e-05, weight decay: 1.56e-06
# Epoch 46/250
# 125/125 - 65s - loss: 4.7664 - acc: 0.1426 - top_5_acc: 0.3731 - top_10_acc: 0.5037 - lr: 3.1250e-05 - 65s/epoch - 518ms/step
#
# Epoch 47: LearningRateScheduler setting learning rate to 6.25e-05.
# learning rate: 6.25e-05, weight decay: 3.13e-06
# Epoch 47/250
# 125/125 - 65s - loss: 4.1749 - acc: 0.3136 - top_5_acc: 0.6074 - top_10_acc: 0.7223 - lr: 6.2500e-05 - 65s/epoch - 518ms/step
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.000125.
# learning rate: 1.25e-04, weight decay: 6.25e-06
# Epoch 48/250
# 125/125 - 65s - loss: 3.6626 - acc: 0.4685 - top_5_acc: 0.7532 - top_10_acc: 0.8334 - lr: 1.2500e-04 - 65s/epoch - 518ms/step
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.00025.
# learning rate: 2.50e-04, weight decay: 1.25e-05
# Epoch 49/250
# 125/125 - 65s - loss: 3.3243 - acc: 0.5754 - top_5_acc: 0.8255 - top_10_acc: 0.8821 - lr: 2.5000e-04 - 65s/epoch - 519ms/step
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.0005.
# learning rate: 5.00e-04, weight decay: 2.50e-05
# Epoch 50/250
# 125/125 - 65s - loss: 3.1136 - acc: 0.6437 - top_5_acc: 0.8670 - top_10_acc: 0.9115 - lr: 5.0000e-04 - 65s/epoch - 519ms/step
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.001.
# learning rate: 1.00e-03, weight decay: 5.00e-05
# Epoch 51/250
# 125/125 - 65s - loss: 3.0341 - acc: 0.6713 - top_5_acc: 0.8823 - top_10_acc: 0.9213 - lr: 0.0010 - 65s/epoch - 519ms/step
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.0009999383162408303.
# learning rate: 1.00e-03, weight decay: 5.00e-05
# Epoch 52/250
# 125/125 - 65s - loss: 2.8312 - acc: 0.7440 - top_5_acc: 0.9165 - top_10_acc: 0.9437 - lr: 9.9994e-04 - 65s/epoch - 519ms/step
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.0009997532801828658.
# learning rate: 1.00e-03, weight decay: 5.00e-05
# Epoch 53/250
# 125/125 - 65s - loss: 2.7212 - acc: 0.7855 - top_5_acc: 0.9323 - top_10_acc: 0.9537 - lr: 9.9975e-04 - 65s/epoch - 519ms/step
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.0009994449374809851.
# learning rate: 9.99e-04, weight decay: 5.00e-05
# Epoch 54/250
# 125/125 - 65s - loss: 2.6447 - acc: 0.8149 - top_5_acc: 0.9439 - top_10_acc: 0.9617 - lr: 9.9944e-04 - 65s/epoch - 520ms/step
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.0009990133642141358.
# learning rate: 9.99e-04, weight decay: 5.00e-05
# Epoch 55/250
# 125/125 - 65s - loss: 2.5774 - acc: 0.8390 - top_5_acc: 0.9532 - top_10_acc: 0.9682 - lr: 9.9901e-04 - 65s/epoch - 519ms/step
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.000998458666866564.
# learning rate: 9.98e-04, weight decay: 4.99e-05
# Epoch 56/250
# 125/125 - 65s - loss: 2.5284 - acc: 0.8562 - top_5_acc: 0.9615 - top_10_acc: 0.9746 - lr: 9.9846e-04 - 65s/epoch - 519ms/step
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.00099778098230154.
# learning rate: 9.98e-04, weight decay: 4.99e-05
# Epoch 57/250
# 125/125 - 65s - loss: 2.4844 - acc: 0.8715 - top_5_acc: 0.9671 - top_10_acc: 0.9781 - lr: 9.9778e-04 - 65s/epoch - 518ms/step
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.0009969804777275899.
# learning rate: 9.97e-04, weight decay: 4.98e-05
# Epoch 58/250
# 125/125 - 65s - loss: 2.4453 - acc: 0.8854 - top_5_acc: 0.9722 - top_10_acc: 0.9823 - lr: 9.9698e-04 - 65s/epoch - 519ms/step
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.000996057350657239.
# learning rate: 9.96e-04, weight decay: 4.98e-05
# Epoch 59/250
# 125/125 - 65s - loss: 2.4158 - acc: 0.8964 - top_5_acc: 0.9764 - top_10_acc: 0.9849 - lr: 9.9606e-04 - 65s/epoch - 519ms/step
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.0009950118288582787.
# learning rate: 9.95e-04, weight decay: 4.98e-05
# Epoch 60/250
# 125/125 - 65s - loss: 2.3836 - acc: 0.9086 - top_5_acc: 0.9806 - top_10_acc: 0.9881 - lr: 9.9501e-04 - 65s/epoch - 519ms/step
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.0009938441702975688.
# learning rate: 9.94e-04, weight decay: 4.97e-05
# Epoch 61/250
# 125/125 - 65s - loss: 2.3545 - acc: 0.9184 - top_5_acc: 0.9837 - top_10_acc: 0.9899 - lr: 9.9384e-04 - 65s/epoch - 519ms/step
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.000992554663077387.
# learning rate: 9.93e-04, weight decay: 4.96e-05
# Epoch 62/250
# 125/125 - 65s - loss: 2.3372 - acc: 0.9255 - top_5_acc: 0.9859 - top_10_acc: 0.9914 - lr: 9.9255e-04 - 65s/epoch - 519ms/step
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.0009911436253643444.
# learning rate: 9.91e-04, weight decay: 4.96e-05
# Epoch 63/250
# 125/125 - 65s - loss: 2.3117 - acc: 0.9338 - top_5_acc: 0.9881 - top_10_acc: 0.9924 - lr: 9.9114e-04 - 65s/epoch - 519ms/step
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.000989611405310883.
# learning rate: 9.90e-04, weight decay: 4.95e-05
# Epoch 64/250
# 125/125 - 65s - loss: 2.2922 - acc: 0.9401 - top_5_acc: 0.9897 - top_10_acc: 0.9940 - lr: 9.8961e-04 - 65s/epoch - 519ms/step
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.0009879583809693738.
# learning rate: 9.88e-04, weight decay: 4.94e-05
# Epoch 65/250
# 125/125 - 65s - loss: 2.2844 - acc: 0.9443 - top_5_acc: 0.9917 - top_10_acc: 0.9953 - lr: 9.8796e-04 - 65s/epoch - 519ms/step
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.0009861849601988384.
# learning rate: 9.86e-04, weight decay: 4.93e-05
# Epoch 66/250
# 125/125 - 65s - loss: 2.2615 - acc: 0.9505 - top_5_acc: 0.9933 - top_10_acc: 0.9962 - lr: 9.8618e-04 - 65s/epoch - 519ms/step
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.0009842915805643156.
# learning rate: 9.84e-04, weight decay: 4.92e-05
# Epoch 67/250
# 125/125 - 65s - loss: 2.2473 - acc: 0.9549 - top_5_acc: 0.9943 - top_10_acc: 0.9968 - lr: 9.8429e-04 - 65s/epoch - 519ms/step
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.000982278709228899.
# learning rate: 9.82e-04, weight decay: 4.91e-05
# Epoch 68/250
# 125/125 - 65s - loss: 2.2332 - acc: 0.9595 - top_5_acc: 0.9951 - top_10_acc: 0.9974 - lr: 9.8228e-04 - 65s/epoch - 518ms/step
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.0009801468428384716.
# learning rate: 9.80e-04, weight decay: 4.90e-05
# Epoch 69/250
# 125/125 - 65s - loss: 2.2272 - acc: 0.9625 - top_5_acc: 0.9959 - top_10_acc: 0.9976 - lr: 9.8015e-04 - 65s/epoch - 518ms/step
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.000977896507399165.
# learning rate: 9.78e-04, weight decay: 4.89e-05
# Epoch 70/250
# 125/125 - 65s - loss: 2.2176 - acc: 0.9652 - top_5_acc: 0.9965 - top_10_acc: 0.9982 - lr: 9.7790e-04 - 65s/epoch - 519ms/step
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.0009755282581475768.
# learning rate: 9.76e-04, weight decay: 4.88e-05
# Epoch 71/250
# 125/125 - 65s - loss: 2.2031 - acc: 0.9688 - top_5_acc: 0.9968 - top_10_acc: 0.9983 - lr: 9.7553e-04 - 65s/epoch - 518ms/step
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.0009730426794137727.
# learning rate: 9.73e-04, weight decay: 4.87e-05
# Epoch 72/250
# 125/125 - 65s - loss: 2.1995 - acc: 0.9693 - top_5_acc: 0.9977 - top_10_acc: 0.9987 - lr: 9.7304e-04 - 65s/epoch - 519ms/step
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.0009704403844771128.
# learning rate: 9.70e-04, weight decay: 4.85e-05
# Epoch 73/250
# 125/125 - 65s - loss: 2.1988 - acc: 0.9707 - top_5_acc: 0.9975 - top_10_acc: 0.9988 - lr: 9.7044e-04 - 65s/epoch - 518ms/step
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.0009677220154149337.
# learning rate: 9.68e-04, weight decay: 4.84e-05
# Epoch 74/250
# 125/125 - 65s - loss: 2.1887 - acc: 0.9740 - top_5_acc: 0.9981 - top_10_acc: 0.9992 - lr: 9.6772e-04 - 65s/epoch - 519ms/step
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.0009648882429441257.
# learning rate: 9.65e-04, weight decay: 4.82e-05
# Epoch 75/250
# 125/125 - 65s - loss: 2.1794 - acc: 0.9754 - top_5_acc: 0.9984 - top_10_acc: 0.9993 - lr: 9.6489e-04 - 65s/epoch - 518ms/step
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.0009619397662556434.
# learning rate: 9.62e-04, weight decay: 4.81e-05
# Epoch 76/250
# 125/125 - 65s - loss: 2.1827 - acc: 0.9744 - top_5_acc: 0.9986 - top_10_acc: 0.9994 - lr: 9.6194e-04 - 65s/epoch - 518ms/step
#
# Epoch 77: LearningRateScheduler setting learning rate to 0.0009588773128419905.
# learning rate: 9.59e-04, weight decay: 4.79e-05
# Epoch 77/250
# 125/125 - 65s - loss: 2.1757 - acc: 0.9776 - top_5_acc: 0.9986 - top_10_acc: 0.9994 - lr: 9.5888e-04 - 65s/epoch - 519ms/step
#
# Epoch 78: LearningRateScheduler setting learning rate to 0.0009557016383177226.
# learning rate: 9.56e-04, weight decay: 4.78e-05
# Epoch 78/250
# 125/125 - 65s - loss: 2.1651 - acc: 0.9794 - top_5_acc: 0.9988 - top_10_acc: 0.9996 - lr: 9.5570e-04 - 65s/epoch - 519ms/step
#
# Epoch 79: LearningRateScheduler setting learning rate to 0.0009524135262330098.
# learning rate: 9.52e-04, weight decay: 4.76e-05
# Epoch 79/250
# 125/125 - 65s - loss: 2.1608 - acc: 0.9804 - top_5_acc: 0.9989 - top_10_acc: 0.9995 - lr: 9.5241e-04 - 65s/epoch - 519ms/step
#
# Epoch 80: LearningRateScheduler setting learning rate to 0.0009490137878803078.
# learning rate: 9.49e-04, weight decay: 4.75e-05
# Epoch 80/250
# 125/125 - 65s - loss: 2.1580 - acc: 0.9806 - top_5_acc: 0.9991 - top_10_acc: 0.9997 - lr: 9.4901e-04 - 65s/epoch - 519ms/step
#
# Epoch 81: LearningRateScheduler setting learning rate to 0.0009455032620941839.
# learning rate: 9.46e-04, weight decay: 4.73e-05
# Epoch 81/250
# 125/125 - 65s - loss: 2.1518 - acc: 0.9826 - top_5_acc: 0.9994 - top_10_acc: 0.9998 - lr: 9.4550e-04 - 65s/epoch - 519ms/step
#
# Epoch 82: LearningRateScheduler setting learning rate to 0.0009418828150443468.
# learning rate: 9.42e-04, weight decay: 4.71e-05
# Epoch 82/250
# 125/125 - 65s - loss: 2.1511 - acc: 0.9830 - top_5_acc: 0.9991 - top_10_acc: 0.9997 - lr: 9.4188e-04 - 65s/epoch - 518ms/step
#
# Epoch 83: LearningRateScheduler setting learning rate to 0.0009381533400219318.
# learning rate: 9.38e-04, weight decay: 4.69e-05
# Epoch 83/250
# 125/125 - 65s - loss: 2.1507 - acc: 0.9826 - top_5_acc: 0.9993 - top_10_acc: 0.9998 - lr: 9.3815e-04 - 65s/epoch - 519ms/step
#
# Epoch 84: LearningRateScheduler setting learning rate to 0.0009343157572190957.
# learning rate: 9.34e-04, weight decay: 4.67e-05
# Epoch 84/250
# 125/125 - 65s - loss: 2.1501 - acc: 0.9829 - top_5_acc: 0.9994 - top_10_acc: 0.9998 - lr: 9.3432e-04 - 65s/epoch - 520ms/step
#
# Epoch 85: LearningRateScheduler setting learning rate to 0.0009303710135019718.
# learning rate: 9.30e-04, weight decay: 4.65e-05
# Epoch 85/250
# 125/125 - 65s - loss: 2.1493 - acc: 0.9831 - top_5_acc: 0.9993 - top_10_acc: 0.9998 - lr: 9.3037e-04 - 65s/epoch - 518ms/step
#
# Epoch 86: LearningRateScheduler setting learning rate to 0.0009263200821770461.
# learning rate: 9.26e-04, weight decay: 4.63e-05
# Epoch 86/250
# 125/125 - 65s - loss: 2.1455 - acc: 0.9836 - top_5_acc: 0.9994 - top_10_acc: 0.9998 - lr: 9.2632e-04 - 65s/epoch - 519ms/step
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.0009221639627510075.
# learning rate: 9.22e-04, weight decay: 4.61e-05
# Epoch 87/250
# 125/125 - 65s - loss: 2.1410 - acc: 0.9850 - top_5_acc: 0.9995 - top_10_acc: 0.9999 - lr: 9.2216e-04 - 65s/epoch - 518ms/step
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.0009179036806841352.
# learning rate: 9.18e-04, weight decay: 4.59e-05
# Epoch 88/250
# 125/125 - 65s - loss: 2.1307 - acc: 0.9869 - top_5_acc: 0.9995 - top_10_acc: 0.9998 - lr: 9.1790e-04 - 65s/epoch - 519ms/step
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.0009135402871372809.
# learning rate: 9.14e-04, weight decay: 4.57e-05
# Epoch 89/250
# 125/125 - 65s - loss: 2.1260 - acc: 0.9878 - top_5_acc: 0.9996 - top_10_acc: 0.9999 - lr: 9.1354e-04 - 65s/epoch - 519ms/step
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.0009090748587125117.
# learning rate: 9.09e-04, weight decay: 4.55e-05
# Epoch 90/250
# 125/125 - 65s - loss: 2.1175 - acc: 0.9895 - top_5_acc: 0.9998 - top_10_acc: 0.9999 - lr: 9.0907e-04 - 65s/epoch - 519ms/step
#
# Epoch 91: LearningRateScheduler setting learning rate to 0.0009045084971874737.
# learning rate: 9.05e-04, weight decay: 4.52e-05
# Epoch 91/250
# 125/125 - 65s - loss: 2.1135 - acc: 0.9903 - top_5_acc: 0.9998 - top_10_acc: 0.9999 - lr: 9.0451e-04 - 65s/epoch - 519ms/step
#
# Epoch 92: LearningRateScheduler setting learning rate to 0.0008998423292435454.
# learning rate: 9.00e-04, weight decay: 4.50e-05
# Epoch 92/250
# 125/125 - 65s - loss: 2.1116 - acc: 0.9906 - top_5_acc: 0.9997 - top_10_acc: 0.9999 - lr: 8.9984e-04 - 65s/epoch - 518ms/step
#
# Epoch 93: LearningRateScheduler setting learning rate to 0.0008950775061878452.
# learning rate: 8.95e-04, weight decay: 4.48e-05
# Epoch 93/250
# 125/125 - 65s - loss: 2.1138 - acc: 0.9898 - top_5_acc: 0.9998 - top_10_acc: 0.9999 - lr: 8.9508e-04 - 65s/epoch - 519ms/step
#
# Epoch 94: LearningRateScheduler setting learning rate to 0.0008902152036691648.
# learning rate: 8.90e-04, weight decay: 4.45e-05
# Epoch 94/250
# 125/125 - 65s - loss: 2.1124 - acc: 0.9908 - top_5_acc: 0.9998 - top_10_acc: 1.0000 - lr: 8.9022e-04 - 65s/epoch - 518ms/step
#
# Epoch 95: LearningRateScheduler setting learning rate to 0.0008852566213878947.
# learning rate: 8.85e-04, weight decay: 4.43e-05
# Epoch 95/250
# 125/125 - 65s - loss: 2.1078 - acc: 0.9914 - top_5_acc: 0.9998 - top_10_acc: 0.9999 - lr: 8.8526e-04 - 65s/epoch - 518ms/step
#
# Epoch 96: LearningRateScheduler setting learning rate to 0.0008802029828000156.
# learning rate: 8.80e-04, weight decay: 4.40e-05
# Epoch 96/250
# 125/125 - 65s - loss: 2.1072 - acc: 0.9915 - top_5_acc: 0.9999 - top_10_acc: 1.0000 - lr: 8.8020e-04 - 65s/epoch - 519ms/step
#
# Epoch 97: LearningRateScheduler setting learning rate to 0.0008750555348152298.
# learning rate: 8.75e-04, weight decay: 4.38e-05
# Epoch 97/250
# 125/125 - 65s - loss: 2.1051 - acc: 0.9916 - top_5_acc: 0.9999 - top_10_acc: 1.0000 - lr: 8.7506e-04 - 65s/epoch - 520ms/step
#
# Epoch 98: LearningRateScheduler setting learning rate to 0.0008698155474893049.
# learning rate: 8.70e-04, weight decay: 4.35e-05
# Epoch 98/250
# 125/125 - 65s - loss: 2.1071 - acc: 0.9916 - top_5_acc: 0.9998 - top_10_acc: 0.9999 - lr: 8.6982e-04 - 65s/epoch - 519ms/step
#
# Epoch 99: LearningRateScheduler setting learning rate to 0.0008644843137107057.
# learning rate: 8.64e-04, weight decay: 4.32e-05
# Epoch 99/250
# 125/125 - 65s - loss: 2.1030 - acc: 0.9920 - top_5_acc: 0.9999 - top_10_acc: 0.9999 - lr: 8.6448e-04 - 65s/epoch - 518ms/step
#
# Epoch 100: LearningRateScheduler setting learning rate to 0.0008590631488815944.
# learning rate: 8.59e-04, weight decay: 4.30e-05
# Epoch 100/250
# 125/125 - 65s - loss: 2.0996 - acc: 0.9919 - top_5_acc: 0.9999 - top_10_acc: 0.9999 - lr: 8.5906e-04 - 65s/epoch - 518ms/step
#
# Epoch 101: LearningRateScheduler setting learning rate to 0.0008535533905932737.
# learning rate: 8.54e-04, weight decay: 4.27e-05
# Epoch 101/250
# 125/125 - 65s - loss: 2.0960 - acc: 0.9928 - top_5_acc: 0.9998 - top_10_acc: 0.9999 - lr: 8.5355e-04 - 65s/epoch - 519ms/step
#
# Epoch 102: LearningRateScheduler setting learning rate to 0.0008479563982961571.
# learning rate: 8.48e-04, weight decay: 4.24e-05
# Epoch 102/250
# 125/125 - 65s - loss: 2.0930 - acc: 0.9933 - top_5_acc: 0.9999 - top_10_acc: 1.0000 - lr: 8.4796e-04 - 65s/epoch - 518ms/step
#
# Epoch 103: LearningRateScheduler setting learning rate to 0.0008422735529643444.
# learning rate: 8.42e-04, weight decay: 4.21e-05
# Epoch 103/250
# 125/125 - 65s - loss: 2.0858 - acc: 0.9945 - top_5_acc: 0.9999 - top_10_acc: 1.0000 - lr: 8.4227e-04 - 65s/epoch - 519ms/step
#
# Epoch 104: LearningRateScheduler setting learning rate to 0.0008365062567548867.
# learning rate: 8.37e-04, weight decay: 4.18e-05
# Epoch 104/250
# 125/125 - 65s - loss: 2.0889 - acc: 0.9940 - top_5_acc: 0.9999 - top_10_acc: 1.0000 - lr: 8.3651e-04 - 65s/epoch - 519ms/step
#
# Epoch 105: LearningRateScheduler setting learning rate to 0.0008306559326618259.
# learning rate: 8.31e-04, weight decay: 4.15e-05
# Epoch 105/250
# 125/125 - 65s - loss: 2.0883 - acc: 0.9938 - top_5_acc: 0.9999 - top_10_acc: 1.0000 - lr: 8.3066e-04 - 65s/epoch - 520ms/step
#
# Epoch 106: LearningRateScheduler setting learning rate to 0.0008247240241650918.
# learning rate: 8.25e-04, weight decay: 4.12e-05
# Epoch 106/250
# 125/125 - 65s - loss: 2.0887 - acc: 0.9939 - top_5_acc: 0.9999 - top_10_acc: 1.0000 - lr: 8.2472e-04 - 65s/epoch - 519ms/step
#
# Epoch 107: LearningRateScheduler setting learning rate to 0.0008187119948743449.
# learning rate: 8.19e-04, weight decay: 4.09e-05
# Epoch 107/250
# 125/125 - 65s - loss: 2.0788 - acc: 0.9948 - top_5_acc: 0.9999 - top_10_acc: 1.0000 - lr: 8.1871e-04 - 65s/epoch - 519ms/step
#
# Epoch 108: LearningRateScheduler setting learning rate to 0.0008126213281678527.
# learning rate: 8.13e-04, weight decay: 4.06e-05
# Epoch 108/250
# 125/125 - 65s - loss: 2.0761 - acc: 0.9951 - top_5_acc: 0.9999 - top_10_acc: 1.0000 - lr: 8.1262e-04 - 65s/epoch - 518ms/step
#
# Epoch 109: LearningRateScheduler setting learning rate to 0.0008064535268264883.
# learning rate: 8.06e-04, weight decay: 4.03e-05
# Epoch 109/250
# 125/125 - 65s - loss: 2.0795 - acc: 0.9950 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 8.0645e-04 - 65s/epoch - 518ms/step
#
# Epoch 110: LearningRateScheduler setting learning rate to 0.0008002101126629421.
# learning rate: 8.00e-04, weight decay: 4.00e-05
# Epoch 110/250
# 125/125 - 65s - loss: 2.0774 - acc: 0.9950 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 8.0021e-04 - 65s/epoch - 520ms/step
#
# Epoch 111: LearningRateScheduler setting learning rate to 0.0007938926261462366.
# learning rate: 7.94e-04, weight decay: 3.97e-05
# Epoch 111/250
# 125/125 - 65s - loss: 2.0783 - acc: 0.9948 - top_5_acc: 0.9999 - top_10_acc: 1.0000 - lr: 7.9389e-04 - 65s/epoch - 519ms/step
#
# Epoch 112: LearningRateScheduler setting learning rate to 0.0007875026260216394.
# learning rate: 7.88e-04, weight decay: 3.94e-05
# Epoch 112/250
# 125/125 - 65s - loss: 2.0703 - acc: 0.9960 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 7.8750e-04 - 65s/epoch - 519ms/step
#
# Epoch 113: LearningRateScheduler setting learning rate to 0.0007810416889260653.
# learning rate: 7.81e-04, weight decay: 3.91e-05
# Epoch 113/250
# 125/125 - 65s - loss: 2.0698 - acc: 0.9962 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 7.8104e-04 - 65s/epoch - 519ms/step
#
# Epoch 114: LearningRateScheduler setting learning rate to 0.0007745114089990659.
# learning rate: 7.75e-04, weight decay: 3.87e-05
# Epoch 114/250
# 125/125 - 65s - loss: 2.0647 - acc: 0.9965 - top_5_acc: 0.9999 - top_10_acc: 1.0000 - lr: 7.7451e-04 - 65s/epoch - 517ms/step
#
# Epoch 115: LearningRateScheduler setting learning rate to 0.0007679133974894983.
# learning rate: 7.68e-04, weight decay: 3.84e-05
# Epoch 115/250
# 125/125 - 65s - loss: 2.0639 - acc: 0.9964 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 7.6791e-04 - 65s/epoch - 519ms/step
#
# Epoch 116: LearningRateScheduler setting learning rate to 0.0007612492823579744.
# learning rate: 7.61e-04, weight decay: 3.81e-05
# Epoch 116/250
# 125/125 - 65s - loss: 2.0621 - acc: 0.9969 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 7.6125e-04 - 65s/epoch - 519ms/step
#
# Epoch 117: LearningRateScheduler setting learning rate to 0.0007545207078751857.
# learning rate: 7.55e-04, weight decay: 3.77e-05
# Epoch 117/250
# 125/125 - 65s - loss: 2.0600 - acc: 0.9970 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 7.5452e-04 - 65s/epoch - 518ms/step
#
# Epoch 118: LearningRateScheduler setting learning rate to 0.0007477293342162038.
# learning rate: 7.48e-04, weight decay: 3.74e-05
# Epoch 118/250
# 125/125 - 65s - loss: 2.0567 - acc: 0.9973 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 7.4773e-04 - 65s/epoch - 519ms/step
#
# Epoch 119: LearningRateScheduler setting learning rate to 0.0007408768370508576.
# learning rate: 7.41e-04, weight decay: 3.70e-05
# Epoch 119/250
# 125/125 - 65s - loss: 2.0542 - acc: 0.9973 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 7.4088e-04 - 65s/epoch - 519ms/step
#
# Epoch 120: LearningRateScheduler setting learning rate to 0.0007339649071302867.
# learning rate: 7.34e-04, weight decay: 3.67e-05
# Epoch 120/250
# 125/125 - 65s - loss: 2.0537 - acc: 0.9974 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 7.3396e-04 - 65s/epoch - 518ms/step
#
# Epoch 121: LearningRateScheduler setting learning rate to 0.0007269952498697733.
# learning rate: 7.27e-04, weight decay: 3.63e-05
# Epoch 121/250
# 125/125 - 65s - loss: 2.0552 - acc: 0.9969 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 7.2700e-04 - 65s/epoch - 519ms/step
#
# Epoch 122: LearningRateScheduler setting learning rate to 0.0007199695849279576.
# learning rate: 7.20e-04, weight decay: 3.60e-05
# Epoch 122/250
# 125/125 - 65s - loss: 2.0520 - acc: 0.9980 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 7.1997e-04 - 65s/epoch - 520ms/step
#
# Epoch 123: LearningRateScheduler setting learning rate to 0.0007128896457825364.
# learning rate: 7.13e-04, weight decay: 3.56e-05
# Epoch 123/250
# 125/125 - 65s - loss: 2.0529 - acc: 0.9975 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 7.1289e-04 - 65s/epoch - 519ms/step
#
# Epoch 124: LearningRateScheduler setting learning rate to 0.0007057571793025545.
# learning rate: 7.06e-04, weight decay: 3.53e-05
# Epoch 124/250
# 125/125 - 65s - loss: 2.0577 - acc: 0.9970 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 7.0576e-04 - 65s/epoch - 519ms/step
#
# Epoch 125: LearningRateScheduler setting learning rate to 0.0006985739453173903.
# learning rate: 6.99e-04, weight decay: 3.49e-05
# Epoch 125/250
# 125/125 - 65s - loss: 2.0505 - acc: 0.9973 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 6.9857e-04 - 65s/epoch - 519ms/step
#
# Epoch 126: LearningRateScheduler setting learning rate to 0.000691341716182545.
# learning rate: 6.91e-04, weight decay: 3.46e-05
# Epoch 126/250
# 125/125 - 65s - loss: 2.0478 - acc: 0.9978 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 6.9134e-04 - 65s/epoch - 518ms/step
#
# Epoch 127: LearningRateScheduler setting learning rate to 0.0006840622763423391.
# learning rate: 6.84e-04, weight decay: 3.42e-05
# Epoch 127/250
# 125/125 - 65s - loss: 2.0444 - acc: 0.9980 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 6.8406e-04 - 65s/epoch - 519ms/step
#
# Epoch 128: LearningRateScheduler setting learning rate to 0.0006767374218896287.
# learning rate: 6.77e-04, weight decay: 3.38e-05
# Epoch 128/250
# 125/125 - 65s - loss: 2.0393 - acc: 0.9985 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 6.7674e-04 - 65s/epoch - 519ms/step
#
# Epoch 129: LearningRateScheduler setting learning rate to 0.0006693689601226458.
# learning rate: 6.69e-04, weight decay: 3.35e-05
# Epoch 129/250
# 125/125 - 65s - loss: 2.0346 - acc: 0.9989 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 6.6937e-04 - 65s/epoch - 518ms/step
#
# Epoch 130: LearningRateScheduler setting learning rate to 0.0006619587090990747.
# learning rate: 6.62e-04, weight decay: 3.31e-05
# Epoch 130/250
# 125/125 - 65s - loss: 2.0353 - acc: 0.9986 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 6.6196e-04 - 65s/epoch - 519ms/step
#
# Epoch 131: LearningRateScheduler setting learning rate to 0.0006545084971874737.
# learning rate: 6.55e-04, weight decay: 3.27e-05
# Epoch 131/250
# 125/125 - 65s - loss: 2.0342 - acc: 0.9986 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 6.5451e-04 - 65s/epoch - 519ms/step
#
# Epoch 132: LearningRateScheduler setting learning rate to 0.000647020162616152.
# learning rate: 6.47e-04, weight decay: 3.24e-05
# Epoch 132/250
# 125/125 - 65s - loss: 2.0346 - acc: 0.9986 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 6.4702e-04 - 65s/epoch - 519ms/step
#
# Epoch 133: LearningRateScheduler setting learning rate to 0.0006394955530196147.
# learning rate: 6.39e-04, weight decay: 3.20e-05
# Epoch 133/250
# 125/125 - 65s - loss: 2.0325 - acc: 0.9987 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 6.3950e-04 - 65s/epoch - 519ms/step
#
# Epoch 134: LearningRateScheduler setting learning rate to 0.0006319365249826865.
# learning rate: 6.32e-04, weight decay: 3.16e-05
# Epoch 134/250
# 125/125 - 65s - loss: 2.0315 - acc: 0.9988 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 6.3194e-04 - 65s/epoch - 519ms/step
#
# Epoch 135: LearningRateScheduler setting learning rate to 0.0006243449435824276.
# learning rate: 6.24e-04, weight decay: 3.12e-05
# Epoch 135/250
# 125/125 - 65s - loss: 2.0292 - acc: 0.9989 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 6.2434e-04 - 65s/epoch - 520ms/step
#
# Epoch 136: LearningRateScheduler setting learning rate to 0.0006167226819279528.
# learning rate: 6.17e-04, weight decay: 3.08e-05
# Epoch 136/250
# 125/125 - 65s - loss: 2.0252 - acc: 0.9991 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 6.1672e-04 - 65s/epoch - 518ms/step
#
# Epoch 137: LearningRateScheduler setting learning rate to 0.0006090716206982714.
# learning rate: 6.09e-04, weight decay: 3.05e-05
# Epoch 137/250
# 125/125 - 65s - loss: 2.0246 - acc: 0.9990 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 6.0907e-04 - 65s/epoch - 518ms/step
#
# Epoch 138: LearningRateScheduler setting learning rate to 0.0006013936476782562.
# learning rate: 6.01e-04, weight decay: 3.01e-05
# Epoch 138/250
# 125/125 - 65s - loss: 2.0242 - acc: 0.9992 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 6.0139e-04 - 65s/epoch - 519ms/step
#
# Epoch 139: LearningRateScheduler setting learning rate to 0.0005936906572928624.
# learning rate: 5.94e-04, weight decay: 2.97e-05
# Epoch 139/250
# 125/125 - 65s - loss: 2.0240 - acc: 0.9991 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 5.9369e-04 - 65s/epoch - 519ms/step
#
# Epoch 140: LearningRateScheduler setting learning rate to 0.0005859645501397047.
# learning rate: 5.86e-04, weight decay: 2.93e-05
# Epoch 140/250
# ...
#
# Epoch 192: LearningRateScheduler setting learning rate to 0.00019978988733705805.
# learning rate: 2.00e-04, weight decay: 9.99e-06
# Epoch 192/250
# 125/125 - 65s - loss: 1.9712 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.9979e-04 - 65s/epoch - 518ms/step
#
# Epoch 193: LearningRateScheduler setting learning rate to 0.00019354647317351188.
# learning rate: 1.94e-04, weight decay: 9.68e-06
# Epoch 193/250
# 125/125 - 65s - loss: 1.9702 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.9355e-04 - 65s/epoch - 518ms/step
#
# Epoch 194: LearningRateScheduler setting learning rate to 0.00018737867183214757.
# learning rate: 1.87e-04, weight decay: 9.37e-06
# Epoch 194/250
# 125/125 - 65s - loss: 1.9701 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.8738e-04 - 65s/epoch - 519ms/step
#
# Epoch 195: LearningRateScheduler setting learning rate to 0.00018128800512565513.
# learning rate: 1.81e-04, weight decay: 9.06e-06
# Epoch 195/250
# 125/125 - 65s - loss: 1.9696 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.8129e-04 - 65s/epoch - 519ms/step
#
# Epoch 196: LearningRateScheduler setting learning rate to 0.00017527597583490823.
# learning rate: 1.75e-04, weight decay: 8.76e-06
# Epoch 196/250
# 125/125 - 65s - loss: 1.9694 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.7528e-04 - 65s/epoch - 518ms/step
#
# Epoch 197: LearningRateScheduler setting learning rate to 0.00016934406733817414.
# learning rate: 1.69e-04, weight decay: 8.47e-06
# Epoch 197/250
# 125/125 - 65s - loss: 1.9683 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.6934e-04 - 65s/epoch - 518ms/step
#
# Epoch 198: LearningRateScheduler setting learning rate to 0.00016349374324511345.
# learning rate: 1.63e-04, weight decay: 8.17e-06
# Epoch 198/250
# 125/125 - 65s - loss: 1.9676 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.6349e-04 - 65s/epoch - 518ms/step
#
# Epoch 199: LearningRateScheduler setting learning rate to 0.00015772644703565563.
# learning rate: 1.58e-04, weight decay: 7.89e-06
# Epoch 199/250
# 125/125 - 65s - loss: 1.9674 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.5773e-04 - 65s/epoch - 518ms/step
#
# Epoch 200: LearningRateScheduler setting learning rate to 0.00015204360170384285.
# learning rate: 1.52e-04, weight decay: 7.60e-06
# Epoch 200/250
# 125/125 - 65s - loss: 1.9671 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.5204e-04 - 65s/epoch - 519ms/step
#
# Epoch 201: LearningRateScheduler setting learning rate to 0.00014644660940672628.
# learning rate: 1.46e-04, weight decay: 7.32e-06
# Epoch 201/250
# 125/125 - 65s - loss: 1.9666 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.4645e-04 - 65s/epoch - 519ms/step
#
# Epoch 202: LearningRateScheduler setting learning rate to 0.00014093685111840566.
# learning rate: 1.41e-04, weight decay: 7.05e-06
# Epoch 202/250
# 125/125 - 65s - loss: 1.9663 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.4094e-04 - 65s/epoch - 518ms/step
#
# Epoch 203: LearningRateScheduler setting learning rate to 0.00013551568628929433.
# learning rate: 1.36e-04, weight decay: 6.78e-06
# Epoch 203/250
# 125/125 - 65s - loss: 1.9659 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.3552e-04 - 65s/epoch - 519ms/step
#
# Epoch 204: LearningRateScheduler setting learning rate to 0.0001301844525106951.
# learning rate: 1.30e-04, weight decay: 6.51e-06
# Epoch 204/250
# 125/125 - 65s - loss: 1.9657 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.3018e-04 - 65s/epoch - 518ms/step
#
# Epoch 205: LearningRateScheduler setting learning rate to 0.0001249444651847702.
# learning rate: 1.25e-04, weight decay: 6.25e-06
# Epoch 205/250
# 125/125 - 65s - loss: 1.9650 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.2494e-04 - 65s/epoch - 518ms/step
#
# Epoch 206: LearningRateScheduler setting learning rate to 0.00011979701719998454.
# learning rate: 1.20e-04, weight decay: 5.99e-06
# Epoch 206/250
# 125/125 - 65s - loss: 1.9648 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.1980e-04 - 65s/epoch - 518ms/step
#
# Epoch 207: LearningRateScheduler setting learning rate to 0.00011474337861210544.
# learning rate: 1.15e-04, weight decay: 5.74e-06
# Epoch 207/250
# 125/125 - 65s - loss: 1.9644 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.1474e-04 - 65s/epoch - 518ms/step
#
# Epoch 208: LearningRateScheduler setting learning rate to 0.0001097847963308351.
# learning rate: 1.10e-04, weight decay: 5.49e-06
# Epoch 208/250
# 125/125 - 65s - loss: 1.9642 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.0978e-04 - 65s/epoch - 519ms/step
#
# Epoch 209: LearningRateScheduler setting learning rate to 0.00010492249381215479.
# learning rate: 1.05e-04, weight decay: 5.25e-06
# Epoch 209/250
# 125/125 - 65s - loss: 1.9636 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.0492e-04 - 65s/epoch - 519ms/step
#
# Epoch 210: LearningRateScheduler setting learning rate to 0.00010015767075645472.
# learning rate: 1.00e-04, weight decay: 5.01e-06
# Epoch 210/250
# 125/125 - 65s - loss: 1.9632 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.0016e-04 - 65s/epoch - 519ms/step
#
# Epoch 211: LearningRateScheduler setting learning rate to 9.549150281252633e-05.
# learning rate: 9.55e-05, weight decay: 4.77e-06
# Epoch 211/250
# 125/125 - 65s - loss: 1.9630 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 9.5492e-05 - 65s/epoch - 518ms/step
#
# Epoch 212: LearningRateScheduler setting learning rate to 9.09251412874882e-05.
# learning rate: 9.09e-05, weight decay: 4.55e-06
# Epoch 212/250
# 125/125 - 65s - loss: 1.9630 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 9.0925e-05 - 65s/epoch - 518ms/step
#
# Epoch 213: LearningRateScheduler setting learning rate to 8.645971286271903e-05.
# learning rate: 8.65e-05, weight decay: 4.32e-06
# Epoch 213/250
# 125/125 - 65s - loss: 1.9624 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 8.6460e-05 - 65s/epoch - 518ms/step
#
# Epoch 214: LearningRateScheduler setting learning rate to 8.209631931586498e-05.
# learning rate: 8.21e-05, weight decay: 4.10e-06
# Epoch 214/250
# 125/125 - 65s - loss: 1.9621 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 8.2096e-05 - 65s/epoch - 519ms/step
#
# Epoch 215: LearningRateScheduler setting learning rate to 7.783603724899258e-05.
# learning rate: 7.78e-05, weight decay: 3.89e-06
# Epoch 215/250
# 125/125 - 65s - loss: 1.9619 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 7.7836e-05 - 65s/epoch - 519ms/step
#
# Epoch 216: LearningRateScheduler setting learning rate to 7.367991782295391e-05.
# learning rate: 7.37e-05, weight decay: 3.68e-06
# Epoch 216/250
# 125/125 - 65s - loss: 1.9615 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 7.3680e-05 - 65s/epoch - 517ms/step
#
# Epoch 217: LearningRateScheduler setting learning rate to 6.962898649802824e-05.
# learning rate: 6.96e-05, weight decay: 3.48e-06
# Epoch 217/250
# 125/125 - 65s - loss: 1.9615 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 6.9629e-05 - 65s/epoch - 517ms/step
#
# Epoch 218: LearningRateScheduler setting learning rate to 6.568424278090446e-05.
# learning rate: 6.57e-05, weight decay: 3.28e-06
# Epoch 218/250
# 125/125 - 65s - loss: 1.9612 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 6.5684e-05 - 65s/epoch - 518ms/step
#
# Epoch 219: LearningRateScheduler setting learning rate to 6.184665997806832e-05.
# learning rate: 6.18e-05, weight decay: 3.09e-06
# Epoch 219/250
# 125/125 - 65s - loss: 1.9611 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 6.1847e-05 - 65s/epoch - 518ms/step
#
# Epoch 220: LearningRateScheduler setting learning rate to 5.811718495565327e-05.
# learning rate: 5.81e-05, weight decay: 2.91e-06
# Epoch 220/250
# 125/125 - 65s - loss: 1.9606 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 5.8117e-05 - 65s/epoch - 519ms/step
#
# Epoch 221: LearningRateScheduler setting learning rate to 5.449673790581611e-05.
# learning rate: 5.45e-05, weight decay: 2.72e-06
# Epoch 221/250
# 125/125 - 65s - loss: 1.9606 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 5.4497e-05 - 65s/epoch - 518ms/step
#
# Epoch 222: LearningRateScheduler setting learning rate to 5.098621211969223e-05.
# learning rate: 5.10e-05, weight decay: 2.55e-06
# Epoch 222/250
# 125/125 - 65s - loss: 1.9604 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 5.0986e-05 - 65s/epoch - 518ms/step
#
# Epoch 223: LearningRateScheduler setting learning rate to 4.758647376699032e-05.
# learning rate: 4.76e-05, weight decay: 2.38e-06
# Epoch 223/250
# 125/125 - 65s - loss: 1.9601 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 4.7586e-05 - 65s/epoch - 518ms/step
#
# Epoch 224: LearningRateScheduler setting learning rate to 4.429836168227736e-05.
# learning rate: 4.43e-05, weight decay: 2.21e-06
# Epoch 224/250
# 125/125 - 65s - loss: 1.9599 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 4.4298e-05 - 65s/epoch - 518ms/step
#
# Epoch 225: LearningRateScheduler setting learning rate to 4.112268715800943e-05.
# learning rate: 4.11e-05, weight decay: 2.06e-06
# Epoch 225/250
# 125/125 - 65s - loss: 1.9598 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 4.1123e-05 - 65s/epoch - 518ms/step
#
# Epoch 226: LearningRateScheduler setting learning rate to 3.806023374435663e-05.
# learning rate: 3.81e-05, weight decay: 1.90e-06
# Epoch 226/250
# 125/125 - 65s - loss: 1.9596 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 3.8060e-05 - 65s/epoch - 518ms/step
#
# Epoch 227: LearningRateScheduler setting learning rate to 3.5111757055874326e-05.
# learning rate: 3.51e-05, weight decay: 1.76e-06
# Epoch 227/250
# 125/125 - 65s - loss: 1.9595 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 3.5112e-05 - 65s/epoch - 519ms/step
#
# Epoch 228: LearningRateScheduler setting learning rate to 3.2277984585066366e-05.
# learning rate: 3.23e-05, weight decay: 1.61e-06
# Epoch 228/250
# 125/125 - 65s - loss: 1.9593 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 3.2278e-05 - 65s/epoch - 518ms/step
#
# Epoch 229: LearningRateScheduler setting learning rate to 2.9559615522887274e-05.
# learning rate: 2.96e-05, weight decay: 1.48e-06
# Epoch 229/250
# 125/125 - 65s - loss: 1.9592 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 2.9560e-05 - 65s/epoch - 519ms/step
#
# Epoch 230: LearningRateScheduler setting learning rate to 2.695732058622735e-05.
# learning rate: 2.70e-05, weight decay: 1.35e-06
# Epoch 230/250
# 125/125 - 65s - loss: 1.9589 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 2.6957e-05 - 65s/epoch - 518ms/step
#
# Epoch 231: LearningRateScheduler setting learning rate to 2.4471741852423235e-05.
# learning rate: 2.45e-05, weight decay: 1.22e-06
# Epoch 231/250
# 125/125 - 65s - loss: 1.9589 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 2.4472e-05 - 65s/epoch - 518ms/step
#
# Epoch 232: LearningRateScheduler setting learning rate to 2.210349260083494e-05.
# learning rate: 2.21e-05, weight decay: 1.11e-06
# Epoch 232/250
# 125/125 - 65s - loss: 1.9588 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 2.2103e-05 - 65s/epoch - 518ms/step
#
# Epoch 233: LearningRateScheduler setting learning rate to 1.985315716152847e-05.
# learning rate: 1.99e-05, weight decay: 9.93e-07
# Epoch 233/250
# 125/125 - 65s - loss: 1.9587 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.9853e-05 - 65s/epoch - 518ms/step
#
# Epoch 234: LearningRateScheduler setting learning rate to 1.7721290771100962e-05.
# learning rate: 1.77e-05, weight decay: 8.86e-07
# Epoch 234/250
# 125/125 - 65s - loss: 1.9585 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.7721e-05 - 65s/epoch - 518ms/step
#
# Epoch 235: LearningRateScheduler setting learning rate to 1.5708419435684463e-05.
# learning rate: 1.57e-05, weight decay: 7.85e-07
# Epoch 235/250
# 125/125 - 65s - loss: 1.9585 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.5708e-05 - 65s/epoch - 518ms/step
#
# Epoch 236: LearningRateScheduler setting learning rate to 1.3815039801161721e-05.
# learning rate: 1.38e-05, weight decay: 6.91e-07
# Epoch 236/250
# 125/125 - 65s - loss: 1.9583 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.3815e-05 - 65s/epoch - 518ms/step
#
# Epoch 237: LearningRateScheduler setting learning rate to 1.2041619030626282e-05.
# learning rate: 1.20e-05, weight decay: 6.02e-07
# Epoch 237/250
# 125/125 - 65s - loss: 1.9583 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.2042e-05 - 65s/epoch - 519ms/step
#
# Epoch 238: LearningRateScheduler setting learning rate to 1.038859468911707e-05.
# learning rate: 1.04e-05, weight decay: 5.19e-07
# Epoch 238/250
# 125/125 - 65s - loss: 1.9582 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.0389e-05 - 65s/epoch - 518ms/step
#
# Epoch 239: LearningRateScheduler setting learning rate to 8.856374635655695e-06.
# learning rate: 8.86e-06, weight decay: 4.43e-07
# Epoch 239/250
# 125/125 - 65s - loss: 1.9581 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 8.8564e-06 - 65s/epoch - 518ms/step
#
# Epoch 240: LearningRateScheduler setting learning rate to 7.445336922613066e-06.
# learning rate: 7.45e-06, weight decay: 3.72e-07
# Epoch 240/250
# 125/125 - 65s - loss: 1.9579 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 7.4453e-06 - 65s/epoch - 519ms/step
#
# Epoch 241: LearningRateScheduler setting learning rate to 6.15582970243117e-06.
# learning rate: 6.16e-06, weight decay: 3.08e-07
# Epoch 241/250
# 125/125 - 65s - loss: 1.9579 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 6.1558e-06 - 65s/epoch - 518ms/step
#
# Epoch 242: LearningRateScheduler setting learning rate to 4.988171141721232e-06.
# learning rate: 4.99e-06, weight decay: 2.49e-07
# Epoch 242/250
# 125/125 - 65s - loss: 1.9580 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 4.9882e-06 - 65s/epoch - 519ms/step
#
# Epoch 243: LearningRateScheduler setting learning rate to 3.942649342761117e-06.
# learning rate: 3.94e-06, weight decay: 1.97e-07
# Epoch 243/250
# 125/125 - 65s - loss: 1.9580 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 3.9426e-06 - 65s/epoch - 518ms/step
#
# Epoch 244: LearningRateScheduler setting learning rate to 3.0195222724102023e-06.
# learning rate: 3.02e-06, weight decay: 1.51e-07
# Epoch 244/250
# 125/125 - 65s - loss: 1.9579 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 3.0195e-06 - 65s/epoch - 519ms/step
#
# Epoch 245: LearningRateScheduler setting learning rate to 2.219017698460002e-06.
# learning rate: 2.22e-06, weight decay: 1.11e-07
# Epoch 245/250
# 125/125 - 65s - loss: 1.9577 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 2.2190e-06 - 65s/epoch - 517ms/step
#
# Epoch 246: LearningRateScheduler setting learning rate to 1.541333133436018e-06.
# learning rate: 1.54e-06, weight decay: 7.71e-08
# Epoch 246/250
# 125/125 - 65s - loss: 1.9579 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 1.5413e-06 - 65s/epoch - 518ms/step
#
# Epoch 247: LearningRateScheduler setting learning rate to 9.866357858642206e-07.
# learning rate: 9.87e-07, weight decay: 4.93e-08
# Epoch 247/250
# 125/125 - 65s - loss: 1.9578 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 9.8664e-07 - 65s/epoch - 518ms/step
#
# Epoch 248: LearningRateScheduler setting learning rate to 5.550625190150483e-07.
# learning rate: 5.55e-07, weight decay: 2.78e-08
# Epoch 248/250
# 125/125 - 65s - loss: 1.9578 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 5.5506e-07 - 65s/epoch - 518ms/step
#
# Epoch 249: LearningRateScheduler setting learning rate to 2.467198171342e-07.
# learning rate: 2.47e-07, weight decay: 1.23e-08
# Epoch 249/250
# 125/125 - 65s - loss: 1.9579 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 2.4672e-07 - 65s/epoch - 518ms/step
#
# Epoch 250: LearningRateScheduler setting learning rate to 6.168375916970615e-08.
# learning rate: 6.17e-08, weight decay: 3.08e-09
# Epoch 250/250
# 125/125 - 65s - loss: 1.9579 - acc: 1.0000 - top_5_acc: 1.0000 - top_10_acc: 1.0000 - lr: 6.1684e-08 - 65s/epoch - 517ms/step

# %%
# Save Model Weights
model.save_weights('model.h5')

# %%
if USE_VAL:
    # Validation Predictions
    y_val_pred = model.predict({ 'frames': X_val, 'non_empty_frame_idxs': NON_EMPTY_FRAME_IDXS_VAL }, verbose=2).argmax(axis=1)
    # Label
    labels = [ORD2SIGN.get(i).replace(' ', '_') for i in range(NUM_CLASSES)]

# %%
# Landmark Weights
for w in model.get_layer('embedding').weights:
    if 'landmark_weights' in w.name:
        weights = scipy.special.softmax(w)

landmarks = ['lips_embedding', 'left_hand_embedding', 'pose_embedding']

for w, lm in zip(weights, landmarks):
    print(f'{lm} weight: {(w*100):.1f}%')
# Out:
# lips_embedding weight: 27.6%
# left_hand_embedding weight: 40.8%
# pose_embedding weight: 31.6%

# %%
def print_classification_report():
    # Classification report for all signs
    classification_report = sklearn.metrics.classification_report(
            y_val,
            y_val_pred,
            target_names=labels,
            output_dict=True,
        )
    # Round Data for better readability
    classification_report = pd.DataFrame(classification_report).T
    classification_report = classification_report.round(2)
    classification_report = classification_report.astype({
            'support': np.uint16,
        })
    # Add signs
    classification_report['sign'] = [e if e in SIGN2ORD else -1 for e in classification_report.index]
    classification_report['sign_ord'] = classification_report['sign'].apply(SIGN2ORD.get).fillna(-1).astype(np.int16)
    # Sort on F1-score
    classification_report = pd.concat((
        classification_report.head(NUM_CLASSES).sort_values('f1-score', ascending=False),
        classification_report.tail(3),
    ))

    pd.options.display.max_rows = 999
    display(classification_report)

# %%
if USE_VAL:
    print_classification_report()

# %%
def plot_history_metric(metric, f_best=np.argmax, ylim=None, yscale=None, yticks=None):
    plt.figure(figsize=(20, 10))
    
    values = history.history[metric]
    N_EPOCHS = len(values)
    val = 'val' in ''.join(history.history.keys())
    # Epoch Ticks
    if N_EPOCHS <= 20:
        x = np.arange(1, N_EPOCHS + 1)
    else:
        x = [1, 5] + [10 + 5 * idx for idx in range((N_EPOCHS - 10) // 5 + 1)]

    x_ticks = np.arange(1, N_EPOCHS+1)

    # Validation
    if val:
        val_values = history.history[f'val_{metric}']
        val_argmin = f_best(val_values)
        plt.plot(x_ticks, val_values, label=f'val')

    # summarize history for accuracy
    plt.plot(x_ticks, values, label=f'train')
    argmin = f_best(values)
    plt.scatter(argmin + 1, values[argmin], color='red', s=75, marker='o', label=f'train_best')
    if val:
        plt.scatter(val_argmin + 1, val_values[val_argmin], color='purple', s=75, marker='o', label=f'val_best')

    plt.title(f'Model {metric}', fontsize=24, pad=10)
    plt.ylabel(metric, fontsize=20, labelpad=10)

    if ylim:
        plt.ylim(ylim)

    if yscale is not None:
        plt.yscale(yscale)
        
    if yticks is not None:
        plt.yticks(yticks, fontsize=16)

    plt.xlabel('epoch', fontsize=20, labelpad=10)        
    plt.tick_params(axis='x', labelsize=8)
    plt.xticks(x, fontsize=16) # set tick step to 1 and let x axis start at 1
    plt.yticks(fontsize=16)
    
    plt.legend(prop={'size': 10})
    plt.grid()
    plt.show()

# %%
if TRAIN_MODEL:
    plot_history_metric('loss', f_best=np.argmin)

# %%
if TRAIN_MODEL:
    plot_history_metric('acc', ylim=[0,1], yticks=np.arange(0.0, 1.1, 0.1))

# %%
if TRAIN_MODEL:
    plot_history_metric('top_5_acc', ylim=[0,1], yticks=np.arange(0.0, 1.1, 0.1))

# %%
if TRAIN_MODEL:
    plot_history_metric('top_10_acc', ylim=[0,1], yticks=np.arange(0.0, 1.1, 0.1))

# %%
# TFLite model for submission
class TFLiteModel(tf.Module):
    def __init__(self, model):
        super(TFLiteModel, self).__init__()

        # Load the feature generation and main models
        self.preprocess_layer = preprocess_layer
        self.model = model
    
    @tf.function(input_signature=[tf.TensorSpec(shape=[None, N_ROWS, N_DIMS], dtype=tf.float32, name='inputs')])
    def __call__(self, inputs):
        # Preprocess Data
        x, non_empty_frame_idxs = self.preprocess_layer(inputs)
        # Add Batch Dimension
        x = tf.expand_dims(x, axis=0)
        non_empty_frame_idxs = tf.expand_dims(non_empty_frame_idxs, axis=0)
        # Make Prediction
        outputs = self.model({ 'frames': x, 'non_empty_frame_idxs': non_empty_frame_idxs })
        # Squeeze Output 1x250 -> 250
        outputs = tf.squeeze(outputs, axis=0)

        # Return a dictionary with the output tensor
        return {'outputs': outputs}

# Define TF Lite Model
tflite_keras_model = TFLiteModel(model)

# Sanity Check
demo_raw_data = load_relevant_data_subset(train['file_path'].values[5])
print(f'demo_raw_data shape: {demo_raw_data.shape}, dtype: {demo_raw_data.dtype}')
demo_output = tflite_keras_model(demo_raw_data)["outputs"]
print(f'demo_output shape: {demo_output.shape}, dtype: {demo_output.dtype}')
demo_prediction = demo_output.numpy().argmax()
print(f'demo_prediction: {demo_prediction}, correct: {train.iloc[0]["sign_ord"]}')
# Out:
# demo_raw_data shape: (29, 543, 3), dtype: float32
# demo_output shape: (250,), dtype: <dtype: 'float32'>
# demo_prediction: 230, correct: 206

# %%
# Create Model Converter
keras_model_converter = tf.lite.TFLiteConverter.from_keras_model(tflite_keras_model)
# Convert Model
tflite_model = keras_model_converter.convert()
# Write Model
with open('/kaggle/working/model.tflite', 'wb') as f:
    f.write(tflite_model)
    
# Zip Model
# !zip submission.zip /kaggle/working/model.tflite
# Out:
#   adding: kaggle/working/model.tflite (deflated 8%)

# %%
# # Verify TFLite model can be loaded and used for prediction
# !pip install tflite-runtime
# import tflite_runtime.interpreter as tflite

# interpreter = tflite.Interpreter("/kaggle/working/model.tflite")
# found_signatures = list(interpreter.get_signature_list().keys())
# prediction_fn = interpreter.get_signature_runner("serving_default")

# output = prediction_fn(inputs=demo_raw_data)
# sign = output['outputs'].argmax()

# print("PRED : ", ORD2SIGN.get(sign), f'[{sign}]')
# print("TRUE : ", train.sign.values[0], f'[{train.sign_ord.values[0]}]')
